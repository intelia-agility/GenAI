# %%
# !pip install google-cloud-documentai

# %%
from google.cloud import documentai_v1 as documentai
import re
from typing import Optional

from google.api_core.client_options import ClientOptions
from google.api_core.exceptions import InternalServerError
from google.api_core.exceptions import RetryError
from google.cloud import documentai  # type: ignore
from google.cloud import storage

from google.api_core.client_options import ClientOptions
from google.api_core.exceptions import InternalServerError
from google.api_core.exceptions import RetryError
from google.cloud import documentai  # type: ignore
from google.cloud import storage
import requests
from google.auth.transport.requests import Request
from google.oauth2 import service_account

# %% [markdown]
# ### setup env values

# %%
# Set your config
project_id = "intelia-health"
location = "us"  # or your region
processor_id ="42c7c4ce5c8d8260"# 

gcs_uri = "gs://health-demo-pdf/Careplan/Download_Sample-Care-Plan_1.pdf"
DATASET_ID = "Whealth"
FHIR_STORE_ID = "whealth_fhirdata"
gcs_output_uri = "gs://health-demo-pdf/Careplan_output/"


fhir_store =f"projects/{project_id}/locations/{location}/datasets/{DATASET_ID}/fhirStores/{FHIR_STORE_ID}"

# %% [markdown]
# ### extract text from pdf

# %%
from google.cloud import documentai_v1 as documentai

def extract_text_from_pdf(project_id, location, processor_id, gcs_input_uri, gcs_output_uri):
    client = documentai.DocumentProcessorServiceClient()
    
    name = f"projects/{project_id}/locations/{location}/processors/{processor_id}"

    gcs_document = documentai.GcsDocument(
        gcs_uri=gcs_input_uri,
        mime_type="application/pdf"
    )

    input_documents = documentai.BatchDocumentsInputConfig(
        gcs_documents=documentai.GcsDocuments(documents=[gcs_document])
    )

    output_config = documentai.DocumentOutputConfig(
        gcs_output_config=documentai.DocumentOutputConfig.GcsOutputConfig(
            gcs_uri=gcs_output_uri
        )
    )

    request = documentai.BatchProcessRequest(
        name=name,
        input_documents=input_documents,
        document_output_config=output_config
    )

    operation = client.batch_process_documents(request=request)
 
    print("Waiting for operation to complete...")
    operation.result(timeout=300)
    print("Processing complete. Check GCS output folder.")
    return operation

# %% [markdown]
# ### extract text, export it into gcs and read it from gcs

# %%
# Step 1: Extract text
text = extract_text_from_pdf(project_id,location, processor_id, gcs_uri,gcs_output_uri)
# Out:
# Waiting for operation to complete...
# Processing complete. Check GCS output folder.

# %%
#get the extracted texts
import re
from typing import Optional

from google.api_core.client_options import ClientOptions
from google.api_core.exceptions import InternalServerError
from google.api_core.exceptions import RetryError
from google.cloud import documentai  # type: ignore
from google.cloud import storage

operation=text
totaldoc=''
if 1==1:
    # After the operation is complete,
    # get output document information from operation metadata
    metadata = documentai.BatchProcessMetadata(operation.metadata)

    if metadata.state != documentai.BatchProcessMetadata.State.SUCCEEDED:
        raise ValueError(f"Batch Process Failed: {metadata.state_message}")

    storage_client = storage.Client()

    print("Output files:")
    # One process per Input Document
    for process in list(metadata.individual_process_statuses):
        # output_gcs_destination format: gs://BUCKET/PREFIX/OPERATION_NUMBER/INPUT_FILE_NUMBER/
        # The Cloud Storage API requires the bucket name and URI prefix separately
        matches = re.match(r"gs://(.*?)/(.*)", process.output_gcs_destination)
        if not matches:
            print(
                "Could not parse output GCS destination:",
                process.output_gcs_destination,
            )
            continue

        output_bucket, output_prefix = matches.groups()

        # Get List of Document Objects from the Output Bucket
        output_blobs = storage_client.list_blobs(output_bucket, prefix=output_prefix)

        # Document AI may output multiple JSON files per source file
        for blob in output_blobs:
            # Document AI should only output JSON files to GCS
            if blob.content_type != "application/json":
                print(
                    f"Skipping non-supported file: {blob.name} - Mimetype: {blob.content_type}"
                )
                continue

            # Download JSON File as bytes object and convert to Document Object
            print(f"Fetching {blob.name}")
            document = documentai.Document.from_json(
                blob.download_as_bytes(), ignore_unknown_fields=True
            )

            # For a full list of Document object attributes, please reference this page:
            # https://cloud.google.com/python/docs/reference/documentai/latest/google.cloud.documentai_v1.types.Document

            # Read the text recognition output from the processor
            print("The document contains the following text:")
            print(document.text)
            totaldoc=totaldoc+'\n'+document.text
# Out:
# Output files:
# Fetching Careplan_output/16475123638674577515/0/Download_Sample-Care-Plan_1-0.json
# The document contains the following text:
# MedicalDirector®
# Sample Care Plan
# This care plan has been generated using Medical Director Care - a fully
# integrated care planning tool within Medical Director software that combines
# patient information with crucial clinical inputs to produce comprehensive
# care plans, increase compliance and promote better patient care.
# Find out more
# HCN Practice Wide Widgets Account MD-Test
# 205 Bourbong Street, Bundaberg, QLD, 4670
# Phone: 1300 788 802 | Fax: 07 4151 1896
# TO BE REVIEWED
# 24/09/2020
# PATIENT DETAILS
# CAREPLAN Graham ANDREWS
# PATIENT'S GOAL
# Gender: Male
# Date of Birth: 14/03/2000
# Social History
# Never smoked
# CAREPLAN MEMBERS
# MS ALISON CAFE
# MEDICATIONS
# Family History
# Dietitian-Paediatric
# Drug name
# Directions
# Condition/s
# Created by Dr A Practitioner
# 205 Bourbong Street, Bundaberg, QLD | 1300 788 802
# Address: 2 Kennedy
# Road Bundaberg QLD
# 4670
# Phone 07 4923 4567
# Mobile: N/A
# Medicare Number :
# 3500265121
# Allergies ANT BITE
# Smoking Never smoked
# Alcohol N/A
# CONDITIONS
# -
# 2002 Ear foreign body removal
# 2013 Ant Bite Allergy
# PAGE 1
# CAREPLAN Lifestyle (General Health)
# HEIGHT
# 160.6
# 23/01/2013
# K10
# N/A
# N/A
# WEIGHT
# 51.9
# 23/01/2013
# GDS
# N/A
# N/A
# BMI
# 20.1
# 23/01/2013
# MMSE
# N/A
# N/A
# WAIST
# N/A
# N/A
# Goal and Health Needs
# Task & Provider Details
# Education on
# Condition
# Educate patients regarding
# their role in optimally
# managing their condition.
# Educate patients regarding their role in optimally managing their condition.
# Review: Every 12 months
# Dr A Practitioner
# GP
# 07/08/2020
# N/A
# Registered Nurse
# (Medical Practice)
# 07/08/2020
# Know how to optimally monitor and manage your condition.
# Review: Every 12 months
# Patient
# 07/08/2020
# Lifestyle modifications as advised by Dietician and Exercise Phys
# iologist. Review: Every 6 months
# Weight
# Management
# Your Ideal Target:
# BMI: Less than 25
# Waist (Male): Less than
# 94cm.
# Waist (Female): Less than
# 80cm
# ALISON CAFE
# Dietician
# 24/06/2020
# N/A
# Exercise Physiologist
# 07/08/2020
# Dr A Practitioner
# GP
# 07/08/2020
# Maintain your weight/prevent weight gain by eating healthy and doing at least 30 minutes of
# physical activity on most days.
# Review: Every
# Healthy Eating
# Advise eating according to
# Australian dietary guidelines,
# with attention to
# quantity and type of food.
# Physical Activity
# and Exercise
# At least 30 minutes of
# Patient
# 07/08/2020
# Advice and education in developing a healthy eating plan.
# Review: Every 6 months
# ALISON CAFE
# Dietician
# 24/06/2020
# Dr A Practitioner
# GP
# 07/08/2020
# Book attend appointment with Dietitian Follow your personal healthy eating plan
# Review: Every 6 months
# Patient
# 07/08/2020
# Advice and education in developing a physical activity and exercise plan.
# Review: Every 6 months
# N/A
# Exercise Physiologist
# Graham ANDREWS CAREPLAN 24/06/20 20
# Dr A Practitioner
# GP
# PAGE 2
# moderate physical activity on
# most if not all days
# of the week (total ≥150
# minutes/week)
# Mobility, Balance
# and Flexibility
# Advice on how to minimis e
# the risk of falls and optimis e
# mobility, balance and
# flexibility.
# Mental and
# Emotional well-
# being
# Review and consider referral
# if a psycological stress or
# issue has been identified.
# Assistance with
# daily living
# Advice on how to optimise
# and preserve independence
# with home assistance
# including support group or
# links to community services.
# 07/08/2020
# 07/08/2020
# Book attend appointment with Exercise Pysiologist Follow your personal activity / exercise
# plan.
# Review: Every 6 months
# Patient
# 07/08/2020
# Advice on how to minimise the risk of falls and optimise mobility, balance and flexibility
# Review: Every 6 months
# N/A
# Exercis e
# Physiologist
# 07/08/2020
# Dr A
# Practitioner
# GP
# 07/08/2020
# N/A
# Occupational
# Thera pist
# 07/08/2020
# N/A
# Osteopath
# 07/08/2020
# N/A
# Physiotherapist
# 07/08/2020
# Book attend appointment with Exercise Physiologist Follow your personal activity / exercis e
# plan.
# Review: Every 6 months
# Patient
# 07/08/2020
# Advise and monitor, Support groups / services, OT referral. Assess psychological impact.
# Review: Every 6 months
# Dr A Practitioner
# GP
# 07/08/2020
# N/A
# Psychologist
# 07/08/2020
# Book attend appointment with Psychologist Support Resources
# https://www.blackdoginstitute.org.au http://www.relationships ns w.org.au
# Review: Every 6 months
# Patient
# 07/08/2020
# Advice on how to optimise and preserve independence with home assistance including support
# group or links to community services.
# Review: Every 6 months
# Dr A Practitioner
# GP
# 07/08/2020
# N/A
# Occupational Therapist
# N/A
# Registered Nurse
# (Aged Care)
# 07/08/2020
# 07/08/2020
# Book attend appointment with Occupational Therapist.
# Review: Every 6 months
# Patient
# 07/08/2020
# Alcohol Intake
# Your Ideal Target:
# No more than 2 Standard
# drinks per day (Male)
# No more than 1 Standard
# drinks per day (Female)
# Advice regarding safe alcohol intake.
# Review: Every 6 months
# N/A
# Drug and Alcohol
# Counsellor
# 07/08/2020
# Dr A Practitioner
# GP
# 07/08/2020
# N/A
# Registered Nurse
# (Medical Practice)
# 07/08/2020
# No more than 2 standard drinks per day for men and women and at least 2 alcohol free
# nights a week.
# Graham ANDREWS CAREPLAN 24/06/20 20
# PAGE 3
# Review: Every
# Patient
# 07/08/2020
# Smoking Cessation Advice on cessation of smoking / pharmacotherapy recommendations.
# Complete cessation.
# Substance
# Dependency
# Advice regarding a substance
# dependency program.
# Review: Every 12 months
# N/A
# Drug and Alcohol
# Counsellor
# 07/08/2020
# Dr A Practitioner
# GP
# N/A
# 07/08/2020
# Mental Health Worker
# 07/08/2020
# Book/attend appointment with (Hypnotherapist, Psychologist, Mental Health Worker)
# Review: Every
# Patient
# 07/08/2020
# Advice regarding a substance dependency program.
# Review: Every 6 months
# N/A
# Drug and Alcohol
# Dr A Practitioner
# GP
# 07/08/2020
# N/A
# Mental Health Worker
# 07/08/2020
# Counsellor
# 07/08/2020
# Book attend appointment with (Hypnotherapist, Psychologist, Mental Health Worker).
# Review: Every 6 months
# Comments: --
# Patient
# 07/08/2020
# Graham ANDREWS CAREPLAN 24/06/20 20
# PAGE 4
# Goal and Health Needs
# Blood Checks
# CAREPLAN Biomedical (General Health)
# Task & Provider Details
# Regular routine bloods reviews.
# Review: Every 6 months
# Regular routine bloods.
# Dr A Practitioner
# GP
# N/A
# Registered Nurse
# (Medical Practice)
# 07/08/2020
# Patient
# 07/08/2020
# 07/08/2020
# Eye Checks
# Eye review to monitor
# refractive errors, age-related
# cataract, glaucoma, age-
# related Macular
# degeneration, and diabetic
# retinopathy, optic nerve
# dis orders or diabetic eye
# problems.
# Dental Health
# Dental review to monitor early
# prevention and intervention.
# Hearing Health
# Detect hearing, balance, and
# related dis orders. Provide
# options such as hearing
# aids, cochlear implants.
# Skin Checks
# Maintain skin integrity with
# early detection of suspicious
# lesions, removal as required.
# Regular skin checks
# Eye review to monitor refractive errors, age-related cataract, glaucoma, age-related Macular
# degeneration, and diabetic retinopathy, optic nerve dis orders or diabetic eye problems.
# Review: Every 12 months
# N/A
# Opthalmologist
# 07/08/2020
# N/A
# Optometrist
# 07/08/2020
# Book attend appointment with Optometrist / Ophthalmologist.
# Review: Every 12 months
# Patient
# 07/08/2020
# Dental review to monitor early prevention and intervention.
# Review: Every 12 months
# N/A
# Dentist
# 07/08/2020
# Book attend appointment with Dentist.
# Review: Every 12 months
# Patient
# 07/08/2020
# Detect hearing, balance, and related dis orders. Provide options such as hearing aids,
# cochlear implants.
# Review: Every 12 months
# N/A
# Audiologist
# 07/08/2020
# Book attend appointment with Audiologist.
# Review: Every 12 months
# Patient
# 07/08/2020
# Maintain skin integrity with early detection of suspicious lesions, removal as required.
# Regular skin checks.
# Review: Every 12 months
# N/A
# Dermatologist
# Graham ANDREWS CAREPLAN 24/06/20 20
# Dr A Practitioner
# GP
# PAGE 5
# 07/08/2020
# 07/08/2020
# Book attend appointment with Dermatologist.
# Review: Every 12 months
# Patient
# 07/08/2020
# Routine Screening
# /Preventative
# Monitor and screen health
# status.
# Cervical smear due:
# Mammogram due:
# Bowel screening
# (FOBT/Colons copy) due:
# Bone density due:
# Health
# Assessments
# Diabetic screen 40-49yo
# Health assessment over
# 75yo
# Monitor and screen health status.
# Review: Every 12 months
# Dr A Practitioner
# GP
# 07/08/2020
# N/A
# Registered Nurse
# (Medical Practice)
# Regular Health assessments.
# Review: Every 12 months
# Dr A Practitioner
# GP
# 07/08/2020
# Diabetes assessment review.
# Review: Every 12 months
# Dr A Practitioner
# GP
# 07/08/2020
# 07/08/2020
# Comments: --
# Graham ANDREWS CAREPLAN 24/06/20 20
# PAGE 6
# CAREPLAN Pharmacological (General Health)
# Goal and Health Needs
# Task & Provider Details
# Medication
# Education and
# Compliance
# Educate patient about the
# importance of adhering to
# pres cribed treatment and
# correct use of medications to
# minimise side effects.
# Medicines Review
# Referral for medication review
# to understand the importance
# of adhering to prescribed
# treatment and correct use of
# medications to minimise side
# effects.
# Immunisation
# Ensure immunisations are up
# to date.
# Educate patient about the importance of adhering to pres cribed treatment and correct use of
# medications to minimise side effects.
# Review: Every 6 months
# Dr A Practitioner
# GP
# 07/08/2020
# N/A
# Registered Nurse
# (Medical Practice)
# 07/08/2020
# Take medications as prescribed.
# Review: Every
# Patient
# 07/08/2020
# Referral for medication review to understand the importance of adhering to prescribed
# treatment and correct use of medications to minimise side effects.
# Review: Every 6 months
# Dr A Practitioner
# GP
# 07/08/2020
# Book attend appointment for a Medicines Review.
# Review: Every 6 months
# Patient
# 07/08/2020
# Ensure immunisations are up to date.
# Review: Every 12 months
# Dr A Practitioner
# GP
# 07/08/2020
# N/A
# Registered Nurse
# (Medical Practice)
# Comments: --
# 07/08/2020
# Graham ANDREWS CAREPLAN 24/06/20 20
# PAGE 7
# ACVRISK
# CAREPLAN Cardiovasular Vascular Disease
# N/A
# N/A
# Goal and Health Needs
# Cardiac Symptoms
# Minimise ongoing cardiac
# symptoms.
# Assess severity and
# individualis e treatment.
# Chest Pain
# Develop an action plan on the
# use of anti-anginals and
# when to ring the ambulance.
# Task & Provider Details
# Minimise ongoing cardiac symptoms.
# Review: Every 3 months
# N/A
# Cardiologist
# 07/08/2020
# Dr A Practitioner
# GP
# 07/08/2020
# Assess severity and individualis e treatment.
# Review: Every 3 months
# N/A
# Cardiologist
# 07/08/2020
# Dr A Practitioner
# GP
# 07/08/2020
# Take your medications daily. Report any side effects or worsening of symptoms
# Review: Every
# Patient
# 07/08/2020
# Develop an action plan on the use of anti-anginals and when to ring the ambulance.
# Review: Every 6 months
# Dr A Practitioner
# GP
# 07/08/2020
# N/A
# Registered Nurse
# (Medical Practice)
# 07/08/2020
# Follow your chest pain action plan.
# Review: Every
# Patient
# 07/08/2020
# Know how and when to call the ambulance.
# Review: Every
# Patient
# 07/08/2020
# Cardiovascular Risk Appropriate advice and care in modifying cardiovascular risk factors. Regularly assess lipids,
# smoking, nutrition, alcohol and physical actiivity Maintain BP
# Factors
# Appropriate advice and care in
# modifying cardiovascular risk
# factors.
# Review: Every 3 months
# N/A
# Cardiologist
# 07/08/2020
# Dr A Practitioner
# GP
# 07/08/2020
# Regularly assess lipids,
# smoking, nutrition, alcohol
# and physical activity
# Maintain BP
# Graham ANDREWS CAREPLAN 24/06/20 20
# PAGE 8
# Medication
# Manage the use of:
# antiplatelets, beta blockers,
# anticoagulants, statins and
# antihypertensives.
# Manage the use of: antiplatelets, beta blockers, anticoagulants, statins and
# antihypertensives.
# Review: Every 3 months
# N/A
# Cardiologist
# 07/08/2020
# Dr A Practitioner
# GP
# 07/08/2020
# Reduce stress as much as possible. Consider referral.
# Stress
# Reduce stress as much as
# possible. Consider referral.
# Review: Every 6 months
# Dr A Practitioner
# GP
# 07/08/2020
# N/A
# Psychologist
# 07/08/2020
# Reduce stress as much as possible.
# Review: Every
# Comments: --
# Patient
# 07/08/2020
# Graham ANDREWS CAREPLAN 24/06/20 20
# PAGE 9
#
# Fetching Careplan_output/16475123638674577515/0/Download_Sample-Care-Plan_1-1.json
# The document contains the following text:
# CAREPLAN Obesity
# Chol
# N/A
# N/A
# HEIGHT
# 160.6
# 23/01/2013
# TRIG
# N/A
# N/A
# WEIGHT
# 51.9
# 23/01/2013
# HDL
# N/A
# N/A
# BP
# 80/50
# 23/03/2014
# LDL
# N/A
# N/A
# ACVRISK
# N/A
# N/A
# Goal and Health Needs
# Task & Provider Details
# Bio-Medical Blood
# Checks
# Bio-medical blood checks to
# obs erve
# improvements/issues.
# Cholesterol levels - Blood
# test, (LDL-C less than 2.0,
# HDL-C greater than 1.0)
# o HbA1c- blood test every 3
# months, acceptable levels
# less than 53mmol/mol
# o Blood glucose levels - blood
# test, healthy between 6-
# 8mmol/L fasting
# Blood Pressure
# BP- to acceptable national
# target (less than 130)
# Your target: Less than 130/80
# Cholesterol levels - Blood test, (LDL-C &lt; 2.0, HDL-C &gt; 1.0) o HbA1c- blood test every 3
# months, acceptable levels &lt; 53mmol/mol o Blood glucose levels - blood test, healthy between
# 6-8mmol/L fasting
# Review: Every 6 months
# Dr A Practitioner
# GP
# 07/08/2020
# N/A
# Registered Nurse
# (Medical Practice)
# 07/08/2020
# Discuss how to optimally monitor and manage your weight loss with GP/ nurse
# Review: Every 6 months
# ALISON CAFE
# Dietician
# 24/06/2020
# Dr A Practitioner
# GP
# 07/08/2020
# N/A
# Registered Nurse
# (Medical Practice)
# Patient
# 07/08/2020
# 07/08/2020
# BP- to acceptable national target (less than 130)
# Review: Every 6 months
# Dr A Practitioner
# GP
# 07/08/2020
# N/A
# Registered Nurse
# (Medical Practice)
# 07/08/2020
# Cardiovascular Risk Appropriate advice and care in managing the cardiovascular system, including postural BP,
# central and peripheral vascular systems
# Appropriate advice and care in
# managing the cardiovascular
# system, including postural
# BP, central and peripheral
# vascular systems.
# Review: Every 6 months
# Dr A Practitioner
# GP
# 07/08/2020
# N/A
# Registered Nurse
# (Medical Practice)
# 07/08/2020
# Comments: --
# Graham ANDREWS CAREPLAN 24/06/20 20
# PAGE 10
# Collection Statement
# Health Communication Network Pty Limited T/A Me dica IDire ct or (ACN 068 458 515) (MedicalDirector) collects personal information and sensitive information
# about you, including health information (pe rs onal health information) when:
# • your doctor creates a care plan (Care Plan) for you using a solution de ve lope d in collaboration by Me dica|Director and Enli Health Intelligence
# Corporation (Enli);
# •
# your doctor and/or other healthcare professionals update or amend your care plan, including your health care goals; and
# •
# you re gister to access your Care Plan.
# Me dica IDire ct or collects your personal health information in order to populate your Care Plan, assist you and your health care provide rs to manage your
# health care goals and for other purposes set out in our Privacy Policy, available at https://www.medicaldire ctor.com/privacy-policy. If you do not provide your
# personal health information to Me dica IDirector, your doctor may not be able to create a care plan for you and/or update that care plan.
# •
# Your care plan may be shared with your other health professionals and any care r nominated by you to assist you with managing your health
# care goals. Personal health information about you that is uploaded into your care plan, whether by you, your doctor or a not her health
# professional, may be disclosed to all parties that are granted access to your care plan. You may grant or withdraw your consent for any
# individual to access your care plan at your absolute discretion by contacting your doctor.
# If there is any pe rs onal health information that you do not wish to be dis closed or otherwise included in you care plan, you must make this known to your
# doctor or other health professional.
# Your care plan will be stored within a cloud solution in Australia. In order to create and share your care plan, your pe rs onal health information will be
# dis closed to Me dica IDirector. Me dicalDire ct or colle cts, stores, uses and dis closes your personal health information in accordance with its Privacy Policy
# available at http://me dicaldire ctor.com/about/privacy. Your pe rs onal health information may also be dis closed by Me dicalDirect or to third parties that help
# Me dica IDirector de live r its services or as required by law, including Enli (which is located in the United States) for the purpose of ope rating, maintaining
# and administering the Care Plan Solution.
# You can re quest access to your personal health information he Id by Me dica IDirector at any time, and (subject to any re te ntion re quire me nts imposed by
# law) you can re quest the deletion of your personal health information.
# By allowing your doctor to create a care plan for you, you consent to the collection, use, storage and dis closure of the personal health information in your
# care plan by Me dica IDire ct or in order to create and manage your care plan and for purposes otherwise set out in this statement and MedicalDirector's
# Privacy Policy.
# MedicalDirector's Privacy Policy explains: (i) how it stores and uses, and how you may access and core ct, your personal health information; (ii) how you
# can lodge a complaint regarding the handling of your pe rs onal health information; and (ii) how it will handle any complaint. If you would like any further
# information about Me dica IDirector's privacy policies or practices, please contact MedicalDirector at the details below:
# Phone: 1300 363 992
# • Email: privacy@medicaldire ctor.com
# • Mail: Privacy Officer, Me dica IDirector, Le ve 15, 477 Pitt Street, Haymarket NSW 2000
# Graham ANDREWS CAREPLAN 24/06/20 20
# PAGE 11

# %%
total_doc=totaldoc

# %% [markdown]
# ### extract Patient entity

# %%
#extract entities
from vertexai.generative_models import GenerativeModel
from google.cloud import aiplatform
import json

# Choose the Gemini model (check if available in your project)
model_name = "gemini-2.5-pro"   # or "gemini-1.5-flash-preview" if faster/lighter

generative_model = GenerativeModel(model_name)
 
schema='''
{ 
  "resourceType" : "Patient",  
  "identifier" : [{ Identifier }], // An identifier for this patient
  "active" : <boolean>, // Whether this patient's record is in active use
  "name" : [{
      "text": "",
      "family": "",
      "given": [""]
    }], // A name associated with the patient
  "telecom" : [{
  // from Element: extension
  "system" : "<code>", // I phone | fax | email | pager | url | sms | other
  "value" : "<string>", // I The actual contact point details
  "use" : "<code>", // home | work | temp | old | mobile - purpose of this contact point
  "rank" : "<positiveInt>", // Specify preferred order of use (1 = highest)
  "period" : { Period } // Time period when the contact point was/is in use
}], // A contact detail for the individual
  "gender" : "<code>", // male | female | other | unknown
  "birthDate" : "<date>", // The date of birth for the individual
  // deceased[x]: Indicates if/when the individual is deceased. One of these 2:
  "deceasedBoolean" : <boolean>,
  "deceasedDateTime" : "<dateTime>",
  "address" : [{
  // from Element: extension
  "use" : "<code>", // home | work | temp | old | billing - purpose of this address
  "type" : "<code>", // postal | physical | both
  "text" : "<string>", // Text representation of the address
  "line" : ["<string>"], // Street name, number, direction & P.O. Box etc.
  "city" : "<string>", // Name of city, town etc.
  "district" : "<string>", // District name (aka county)
  "state" : "<string>", // Sub-unit of country (abbreviations ok)
  "postalCode" : "<string>", // Postal code for area
  "country" : "<string>", // Country (e.g. may be ISO 3166 2 or 3 letter code)
  "period" : { Period } // Time period when address was/is in use
}], // An address for the individual
  "maritalStatus" : { 
  // from Element: extension
  "coding" : [{ Coding }], // Code defined by a terminology system
  "text" : "<string>" // Plain text representation of the concept
}, // Marital (civil) status of a patient
  "generalPractitioner" : [{  "<string>" }], // Patient's nominated primary care provider
   
}
'''

# Create prompt
prompt = f"""
You are a clinical data extraction assistant.
Your job is to extract patient information from a clinical document or care plan.
Return the output as a structured FHIR R4 Patient.
⚠ Only include fields that are present or can be inferred from the text. Do not include empty strings, empty arrays ([]) or null values.

follow JSON schema.<JSONSchema>{json.dumps(schema)}</JSONSchema>

Text:
{total_doc}
"""

# Generate response
response = generative_model.generate_content(prompt)

# Print structured output
print(response.text)

patient=response.text
# Out:
# ```json
# {
#   "resourceType": "Patient",
#   "identifier": [
#     {
#       "type": {
#         "text": "Medicare Number"
#       },
#       "system": "http://ns.electronichealth.net.au/id/medicare-number",
#       "value": "3500265121"
#     }
#   ],
#   "active": true,
#   "name": [
#     {
#       "text": "Graham ANDREWS",
#       "family": "ANDREWS",
#       "given": [
#         "Graham"
#       ]
#     }
#   ],
#   "telecom": [
#     {
#       "system": "phone",
#       "value": "07 4923 4567",
#       "use": "home"
#     }
#   ],
#   "gender": "male",
#   "birthDate": "2000-03-14",
#   "address": [
#     {
#       "use": "home",
#       "text": "2 Kennedy Road Bundaberg QLD 4670",
#       "line": [
#         "2 Kennedy Road"
#       ],
#       "city": "Bundaberg",
#       "state": "QLD",
#       "postalCode": "4670"
#     }
#   ],
#   "generalPractitioner": [
#     {
#       "display": "Dr A Practitioner"
#     }
#   ]
# }
# ```

# %% [markdown]
# ### extract Condition entities

# %%
#extract entities
from vertexai.generative_models import GenerativeModel
from google.cloud import aiplatform
import json

# Choose the Gemini model (check if available in your project)
model_name = "gemini-2.5-pro"   # or "gemini-1.5-flash-preview" if faster/lighter

generative_model = GenerativeModel(model_name)


#prompt = f"Extract clinical entities from the following text:\n{document.text}"

schema='''
{
  "id": "",
  "identifier": [{
    "system": "",
    "value": ""
  }],
  "meta": {
    "source": "",
    "tag": [{
      "code": "",
      "display": "",
      "system": ""
    }]
  },
  "clinicalStatus": {
    "coding": [{
      "code": "",
      "display": "",
      "system": ""
    }]
  },
  "verificationStatus": {
    "coding": [{
      "code": "",
      "display": "",
      "system": ""
    }]
  },
  "category": [{
    "coding": [{
      "code": "",
      "display": "",
      "system": ""
    }],
    "text": ""
  }],
  "code": {
    "coding": [{
      "code": "",
      "display": "",
      "system": ""
    }],
    "text": ""
  },
  "bodySite": [{
    "coding": [{
      "code": "",
      "display": "",
      "system": ""
    }],
    "text": ""
  }],
  "subject": {
    "reference": ""
  },
  "encounter": {
    "reference": ""
  },
  "onsetDateTime": "",
  "onsetPeriod": {
    "start": "",
    "end": ""
  },
  "recordedDate": "",
  "asserter": {
    "display": "",
    "reference": ""
  },
  "recorder": {
    "display": "",
    "reference": ""
  },
  "note": [{
    "text": ""
  }]
}


'''

# Create prompt
prompt = f"""
You are a clinical data extraction assistant.
Your job is to extract patient information from a clinical document or care plan.
Return the output as a structured FHIR R4 Condition.
⚠ Only include fields that are present or can be inferred from the text. Do not include empty strings, empty arrays ([]) or null values.

follow JSON schema.<JSONSchema>{json.dumps(schema)}</JSONSchema>
each condition should be separated from the other one using '----------'
Text:
{total_doc}
"""

# Generate response
response = generative_model.generate_content(prompt)

# Print structured output
print(response.text)

condition=response.text
# Out:
# ```json
# {
#   "resourceType": "Condition",
#   "clinicalStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#         "code": "resolved",
#         "display": "Resolved"
#       }
#     ]
#   },
#   "category": [
#     {
#       "coding": [
#         {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "problem-list-item",
#           "display": "Problem List Item"
#         }
#       ]
#     }
#   ],
#   "code": {
#     "text": "Ear foreign body removal"
#   },
#   "subject": {
#     "reference": "Patient/GrahamANDREWS"
#   },
#   "onsetDateTime": "2002",
#   "recordedDate": "2020-06-24",
#   "asserter": {
#     "display": "Dr A Practitioner"
#   }
# }
# ```
# ----------
# ```json
# {
#   "resourceType": "Condition",
#   "clinicalStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#         "code": "active",
#         "display": "Active"
#       }
#     ]
#   },
#   "verificationStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#         "code": "confirmed",
#         "display": "Confirmed"
#       }
#     ]
#   },
#   "category": [
#     {
#       "coding": [
#         {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "problem-list-item",
#           "display": "Problem List Item"
#         }
#       ]
#     }
#   ],
#   "code": {
#     "text": "Ant Bite Allergy"
#   },
#   "subject": {
#     "reference": "Patient/GrahamANDREWS"
#   },
#   "onsetDateTime": "2013",
#   "recordedDate": "2020-06-24",
#   "asserter": {
#     "display": "Dr A Practitioner"
#   }
# }
# ```
# ----------
# ```json
# {
#   "resourceType": "Condition",
#   "clinicalStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#         "code": "active",
#         "display": "Active"
#       }
#     ]
#   },
#   "verificationStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#         "code": "confirmed",
#         "display": "Confirmed"
#       }
#     ]
#   },
#   "category": [
#     {
#       "coding": [
#         {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "encounter-diagnosis",
#           "display": "Encounter Diagnosis"
#         }
#       ]
#     }
#   ],
#   "code": {
#     "text": "Cardiovasular Vascular Disease"
#   },
#   "subject": {
#     "reference": "Patient/GrahamANDREWS"
#   },
#   "recordedDate": "2020-06-24",
#   "asserter": {
#     "display": "Dr A Practitioner"
#   }
# }
# ```
# ----------
# ```json
# {
#   "resourceType": "Condition",
#   "clinicalStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#         "code": "active",
#         "display": "Active"
#       }
#     ]
#   },
#   "verificationStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#         "code": "confirmed",
#         "display": "Confirmed"
#       }
#     ]
#   },
#   "category": [
#     {
#       "coding": [
#         {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "encounter-diagnosis",
#           "display": "Encounter Diagnosis"
#         }
#       ]
#     }
#   ],
#   "code": {
#     "text": "Obesity"
#   },
#   "subject": {
#     "reference": "Patient/GrahamANDREWS"
#   },
#   "recordedDate": "2020-06-24",
#   "asserter": {
#     "display": "Dr A Practitioner"
#   }
# }
# ```

# %% [markdown]
# ### extract Careplan entity

# %%
#extract entities
from vertexai.generative_models import GenerativeModel
from google.cloud import aiplatform
import json

# Choose the Gemini model (check if available in your project)
model_name = "gemini-2.5-pro"   # or "gemini-1.5-flash-preview" if faster/lighter

generative_model = GenerativeModel(model_name)


#prompt = f"Extract clinical entities from the following text:\n{document.text}"

schema='''
{
  "id": "",
  "intent":"plan",
  "status": "",
  "title": "",
  "description": "",
  "created": "",
  "period": {
    "start": "",
    "end": ""
  },
  "subject": {
    "reference": ""
  },
  "author": {
    "display": ""    
  },
  "category": [
    {
      "coding": [
        {
          "code": "",
          "display": "",
          "system": ""
        }
      ],
      "text": ""
    }
  ],
  "addresses": [
    {
      "display": "",
      "reference": ""
    }
  ],
  "activity": [
    {
      "detail": {
        "description": ""
        "status":"in-progress"
      },
      "progress": [
        {
          "text": ""
        }
      ]
    }
  ],
  "note": [
    {
      "text": ""
    }
  ]
}


'''


# Create prompt
prompt = f"""
You are a clinical data extraction assistant.
Your job is to extract patient information from a clinical document or care plan.
Return the output as a structured FHIR R4 CarePlan.
⚠ Only include fields that are present or can be inferred from the text. Do not include empty strings, empty arrays ([]) or null values.

follow JSON schema.<JSONSchema>{json.dumps(schema)}</JSONSchema>

Text:
{total_doc}
"""

# Generate response
response = generative_model.generate_content(prompt)

# Print structured output
print(response.text)

careplan=response.text
# Out:
# ```json
# {
#   "id": "careplan-graham-andrews",
#   "intent": "plan",
#   "status": "active",
#   "title": "CAREPLAN Graham ANDREWS",
#   "description": "Comprehensive care plan for Graham Andrews focusing on lifestyle, biomedical, pharmacological, cardiovascular, and obesity management.",
#   "created": "2020-06-24",
#   "period": {
#     "start": "2020-06-24",
#     "end": "2020-09-24"
#   },
#   "subject": {
#     "reference": "Patient/graham-andrews",
#     "display": "Graham ANDREWS"
#   },
#   "author": {
#     "display": "Dr A Practitioner"
#   },
#   "category": [
#     {
#       "text": "Lifestyle (General Health)"
#     },
#     {
#       "text": "Biomedical (General Health)"
#     },
#     {
#       "text": "Pharmacological (General Health)"
#     },
#     {
#       "text": "Cardiovasular Vascular Disease"
#     },
#     {
#       "text": "Obesity"
#     }
#   ],
#   "addresses": [
#     {
#       "display": "Ant Bite Allergy"
#     },
#     {
#       "display": "Obesity"
#     },
#     {
#       "display": "Cardiovascular Disease"
#     }
#   ],
#   "activity": [
#     {
#       "detail": {
#         "description": "Education on Condition: Educate patients regarding their role in optimally managing their condition.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Educate patients regarding their role in optimally managing their condition. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Know how to optimally monitor and manage your condition. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Weight Management: Your Ideal Target: BMI: Less than 25, Waist (Male): Less than 94cm.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for ALISON CAFE (Dietician), Exercise Physiologist, Dr A Practitioner (GP): Lifestyle modifications as advised by Dietician and Exercise Physiologist. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Maintain your weight/prevent weight gain by eating healthy and doing at least 30 minutes of physical activity on most days. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Healthy Eating: Advise eating according to Australian dietary guidelines, with attention to quantity and type of food.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for ALISON CAFE (Dietician), Dr A Practitioner (GP): Advice and education in developing a healthy eating plan. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Dietitian. Follow your personal healthy eating plan. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Physical Activity and Exercise: At least 30 minutes of moderate physical activity on most if not all days of the week (total ≥150 minutes/week).",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Exercise Physiologist, Dr A Practitioner (GP): Advice and education in developing a physical activity and exercise plan. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Exercise Pysiologist. Follow your personal activity / exercise plan. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Mobility, Balance and Flexibility: Advice on how to minimise the risk of falls and optimise mobility, balance and flexibility.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Exercise Physiologist, Dr A Practitioner (GP), Occupational Therapist, Osteopath, Physiotherapist: Advice on how to minimise the risk of falls and optimise mobility, balance and flexibility. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Exercise Physiologist. Follow your personal activity / exercise plan. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Mental and Emotional well-being: Review and consider referral if a psychological stress or issue has been identified.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Psychologist: Advise and monitor, Support groups / services, OT referral. Assess psychological impact. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Psychologist. Support Resources https://www.blackdoginstitute.org.au http://www.relationships nsw.org.au. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Assistance with daily living: Advice on how to optimise and preserve independence with home assistance including support group or links to community services.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Occupational Therapist, Registered Nurse (Aged Care): Advice on how to optimise and preserve independence with home assistance including support group or links to community services. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Occupational Therapist. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Alcohol Intake: Your Ideal Target: No more than 2 Standard drinks per day (Male).",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Drug and Alcohol Counsellor, Dr A Practitioner (GP), Registered Nurse (Medical Practice): Advice regarding safe alcohol intake. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: No more than 2 standard drinks per day for men and women and at least 2 alcohol free nights a week. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Smoking Cessation: Complete cessation.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Drug and Alcohol Counsellor, Dr A Practitioner (GP), Mental Health Worker: Advice on cessation of smoking / pharmacotherapy recommendations. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Book/attend appointment with (Hypnotherapist, Psychologist, Mental Health Worker). Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Substance Dependency: Advice regarding a substance dependency program.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Drug and Alcohol Counsellor, Dr A Practitioner (GP), Mental Health Worker: Advice regarding a substance dependency program. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with (Hypnotherapist, Psychologist, Mental Health Worker). Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Blood Checks: Regular routine bloods reviews.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Regular routine bloods. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Regular routine bloods."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Eye Checks: Eye review to monitor refractive errors, age-related cataract, glaucoma, age-related Macular degeneration, and diabetic retinopathy, optic nerve disorders or diabetic eye problems.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Opthalmologist, Optometrist: Eye review to monitor refractive errors, age-related cataract, glaucoma, age-related Macular degeneration, and diabetic retinopathy, optic nerve dis orders or diabetic eye problems. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Optometrist / Ophthalmologist. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Dental Health: Dental review to monitor early prevention and intervention.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dentist: Dental review to monitor early prevention and intervention. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Dentist. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Hearing Health: Detect hearing, balance, and related disorders. Provide options such as hearing aids, cochlear implants.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Audiologist: Detect hearing, balance, and related dis orders. Provide options such as hearing aids, cochlear implants. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Audiologist. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Skin Checks: Maintain skin integrity with early detection of suspicious lesions, removal as required. Regular skin checks.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dermatologist, Dr A Practitioner (GP): Maintain skin integrity with early detection of suspicious lesions, removal as required. Regular skin checks. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Dermatologist. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Routine Screening /Preventative: Monitor and screen health status. Cervical smear due: Mammogram due: Bowel screening (FOBT/Colons copy) due: Bone density due:",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Monitor and screen health status. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Health Assessments: Diabetic screen 40-49yo, Health assessment over 75yo.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP): Regular Health assessments. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Dr A Practitioner (GP): Diabetes assessment review. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Medication Education and Compliance: Educate patient about the importance of adhering to prescribed treatment and correct use of medications to minimise side effects.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Educate patient about the importance of adhering to pres cribed treatment and correct use of medications to minimise side effects. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Take medications as prescribed. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Medicines Review: Referral for medication review to understand the importance of adhering to prescribed treatment and correct use of medications to minimise side effects.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP): Referral for medication review to understand the importance of adhering to prescribed treatment and correct use of medications to minimise side effects. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment for a Medicines Review. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Immunisation: Ensure immunisations are up to date.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Ensure immunisations are up to date. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Cardiac Symptoms: Minimise ongoing cardiac symptoms. Assess severity and individualise treatment.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Cardiologist, Dr A Practitioner (GP): Minimise ongoing cardiac symptoms. Review: Every 3 months."
#         },
#         {
#           "text": "Task for Cardiologist, Dr A Practitioner (GP): Assess severity and individualise treatment. Review: Every 3 months."
#         },
#         {
#           "text": "Task for Patient: Take your medications daily. Report any side effects or worsening of symptoms. Review: Every 3 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Chest Pain: Develop an action plan on the use of anti-anginals and when to ring the ambulance.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Develop an action plan on the use of anti-anginals and when to ring the ambulance. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Follow your chest pain action plan. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Know how and when to call the ambulance. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Cardiovascular Risk Factors: Appropriate advice and care in modifying cardiovascular risk factors. Regularly assess lipids, smoking, nutrition, alcohol and physical activity Maintain BP.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Cardiologist, Dr A Practitioner (GP): Appropriate advice and care in modifying cardiovascular risk factors. Review: Every 3 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Medication (Cardiovascular): Manage the use of: antiplatelets, beta blockers, anticoagulants, statins and antihypertensives.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Cardiologist, Dr A Practitioner (GP): Manage the use of: antiplatelets, beta blockers, anticoagulants, statins and antihypertensives. Review: Every 3 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Stress: Reduce stress as much as possible. Consider referral.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Psychologist: Reduce stress as much as possible. Consider referral. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Reduce stress as much as possible. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Bio-Medical Blood Checks (Obesity): Bio-medical blood checks to observe improvements/issues. Cholesterol levels - Blood test, (LDL-C less than 2.0, HDL-C greater than 1.0) o HbA1c- blood test every 3 months, acceptable levels less than 53mmol/mol o Blood glucose levels - blood test, healthy between 6-8mmol/L fasting.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Cholesterol levels - Blood test, (LDL-C < 2.0, HDL-C > 1.0) o HbA1c- blood test every 3 months, acceptable levels < 53mmol/mol o Blood glucose levels - blood test, healthy between 6-8mmol/L fasting. Review: Every 6 months."
#         },
#         {
#           "text": "Task for ALISON CAFE (Dietician), Dr A Practitioner (GP), Registered Nurse (Medical Practice), Patient: Discuss how to optimally monitor and manage your weight loss with GP/ nurse. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Blood Pressure (Obesity): BP- to acceptable national target (less than 130). Your target: Less than 130/80.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): BP- to acceptable national target (less than 130). Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Cardiovascular Risk (Obesity): Appropriate advice and care in managing the cardiovascular system, including postural BP, central and peripheral vascular systems.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Appropriate advice and care in managing the cardiovascular system, including postural BP, central and peripheral vascular systems. Review: Every 6 months."
#         }
#       ]
#     }
#   ]
# }
# ```

# %% [markdown]
# ### store entites in FHIR data store

# %%
#format enities in fhir
import re
import json
import uuid
from datetime import datetime

def func_extract_json(text):
    # Extract text from Gemini
    output = text

    # Try to extract JSON block using regex
    match = re.search(r'\{.*\}', output, re.DOTALL)
    if match:
        json_str = match.group(0)
        entities = json.loads(json_str)
    else:
        raise ValueError("No valid JSON found in LLM response")
    return entities
 
#strore result in fhir store
from google.oauth2 import service_account
from googleapiclient.discovery import build
import json

# credentials_path = "path/to/your-service-account.json"

# # Authenticate
# scopes = ["https://www.googleapis.com/auth/cloud-platform"]
# credentials = service_account.Credentials.from_service_account_file(
#     credentials_path, scopes=scopes
# )

from google.auth import default
from googleapiclient.discovery import build

credentials, project_id = default()
import google.auth
from google.auth.transport.requests import Request

creds, project_id = google.auth.default()
creds.refresh(Request())

print("✅ Access token:", creds.token[:20], "...")  # Just to confirm it's working


service = build("healthcare", "v1", credentials=credentials) 

 
import google.auth
from google.auth.transport.requests import AuthorizedSession

credentials, project_id = google.auth.default()
authed_session = AuthorizedSession(credentials)


def upload_fhir_resource(resource):

    resource_type = resource["resourceType"]
    print(f"Uploading {resource_type}:\n{json.dumps(resource, indent=2)}")

    try:
       #this is also correct
        response = authed_session.post(
            #f"https://healthcare.googleapis.com/v1/{fhir_store}/fhir/Patient",
             f"https://healthcare.googleapis.com/v1/{fhir_store}/fhir/{resource_type}",
            json=resource
        )
        response.raise_for_status()
        created_patient = response.json()
        response=created_patient
        print("Created Patient:", created_patient)

    except Exception as e:
        print(f"❌ Failed to upload {resource_type}:\n{e}")
    return response
# Out:
# ✅ Access token: ya29.c.c0ASRK0GZKSaI ...

# %%
fhir_patient=func_extract_json(patient)
fhir_patient['resourceType']='Patient'
try:
    fhir_patient.pop('id') 
except:
    s=''
res=upload_fhir_resource(fhir_patient)
# Out:
# Uploading Patient:
# {
#   "resourceType": "Patient",
#   "identifier": [
#     {
#       "type": {
#         "text": "Medicare Number"
#       },
#       "system": "http://ns.electronichealth.net.au/id/medicare-number",
#       "value": "3500265121"
#     }
#   ],
#   "active": true,
#   "name": [
#     {
#       "text": "Graham ANDREWS",
#       "family": "ANDREWS",
#       "given": [
#         "Graham"
#       ]
#     }
#   ],
#   "telecom": [
#     {
#       "system": "phone",
#       "value": "07 4923 4567",
#       "use": "home"
#     }
#   ],
#   "gender": "male",
#   "birthDate": "2000-03-14",
#   "address": [
#     {
#       "use": "home",
#       "text": "2 Kennedy Road Bundaberg QLD 4670",
#       "line": [
#         "2 Kennedy Road"
#       ],
#       "city": "Bundaberg",
#       "state": "QLD",
#       "postalCode": "4670"
#     }
#   ],
#   "generalPractitioner": [
#     {
#       "display": "Dr A Practitioner"
#     }
#   ]
# }
# Created Patient: {'active': True, 'address': [{'city': 'Bundaberg', 'line': ['2 Kennedy Road'], 'postalCode': '4670', 'state': 'QLD', 'text': '2 Kennedy Road Bundaberg QLD 4670', 'use': 'home'}], 'birthDate': '2000-03-14', 'gender': 'male', 'generalPractitioner': [{'display': 'Dr A Practitioner'}], 'id': '0a8212cc-ad5e-40e0-b47f-14760116b0cc', 'identifier': [{'system': 'http://ns.electronichealth.net.au/id/medicare-number', 'type': {'text': 'Medicare Number'}, 'value': '3500265121'}], 'meta': {'lastUpdated': '2025-07-06T01:53:15.945794+00:00', 'versionId': 'MTc1MTc2Njc5NTk0NTc5NDAwMA'}, 'name': [{'family': 'ANDREWS', 'given': ['Graham'], 'text': 'Graham ANDREWS'}], 'resourceType': 'Patient', 'telecom': [{'system': 'phone', 'use': 'home', 'value': '07 4923 4567'}]}

# %%
id='0a8212cc-ad5e-40e0-b47f-14760116b0cc'

# %%
for cndtion in condition.split('----------'):    
    if (cndtion.strip()!=''):
            try:
                print(cndtion)            
                fhir_condition=func_extract_json(cndtion)
                #fhir_condition['identifier']=f"{res['id']}"
                try:
                    fhir_condition['subject']['reference']=f"Patient/{res['id']}"
                except:
                    fhir_condition['subject'] = {"reference": f"Patient/{res['id']}"}

                fhir_condition['resourceType']='Condition'
                #fhir_condition.pop('id')
                resccnd=upload_fhir_resource(fhir_condition)
            except:
                continue
# Out:
# ```json
# {
#   "resourceType": "Condition",
#   "clinicalStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#         "code": "resolved",
#         "display": "Resolved"
#       }
#     ]
#   },
#   "category": [
#     {
#       "coding": [
#         {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "problem-list-item",
#           "display": "Problem List Item"
#         }
#       ]
#     }
#   ],
#   "code": {
#     "text": "Ear foreign body removal"
#   },
#   "subject": {
#     "reference": "Patient/GrahamANDREWS"
#   },
#   "onsetDateTime": "2002",
#   "recordedDate": "2020-06-24",
#   "asserter": {
#     "display": "Dr A Practitioner"
#   }
# }
# ```
#
# Uploading Condition:
# {
#   "resourceType": "Condition",
#   "clinicalStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#         "code": "resolved",
#         "display": "Resolved"
#       }
#     ]
#   },
#   "category": [
#     {
#       "coding": [
#         {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "problem-list-item",
#           "display": "Problem List Item"
#         }
#       ]
#     }
#   ],
#   "code": {
#     "text": "Ear foreign body removal"
#   },
#   "subject": {
#     "reference": "Patient/0a8212cc-ad5e-40e0-b47f-14760116b0cc"
#   },
#   "onsetDateTime": "2002",
#   "recordedDate": "2020-06-24",
#   "asserter": {
#     "display": "Dr A Practitioner"
#   }
# }
# Created Patient: {'asserter': {'display': 'Dr A Practitioner'}, 'category': [{'coding': [{'code': 'problem-list-item', 'display': 'Problem List Item', 'system': 'http://terminology.hl7.org/CodeSystem/condition-category'}]}], 'clinicalStatus': {'coding': [{'code': 'resolved', 'display': 'Resolved', 'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical'}]}, 'code': {'text': 'Ear foreign body removal'}, 'id': 'a4d078c8-876c-4b48-90c1-0b04d32b30e8', 'meta': {'lastUpdated': '2025-07-06T01:53:50.258419+00:00', 'versionId': 'MTc1MTc2NjgzMDI1ODQxOTAwMA'}, 'onsetDateTime': '2002', 'recordedDate': '2020-06-24', 'resourceType': 'Condition', 'subject': {'reference': 'Patient/0a8212cc-ad5e-40e0-b47f-14760116b0cc'}}
#
# ```json
# {
#   "resourceType": "Condition",
#   "clinicalStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#         "code": "active",
#         "display": "Active"
#       }
#     ]
#   },
#   "verificationStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#         "code": "confirmed",
#         "display": "Confirmed"
#       }
#     ]
#   },
#   "category": [
#     {
#       "coding": [
#         {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "problem-list-item",
#           "display": "Problem List Item"
#         }
#       ]
#     }
#   ],
#   "code": {
#     "text": "Ant Bite Allergy"
#   },
#   "subject": {
#     "reference": "Patient/GrahamANDREWS"
#   },
#   "onsetDateTime": "2013",
#   "recordedDate": "2020-06-24",
#   "asserter": {
#     "display": "Dr A Practitioner"
#   }
# }
# ```
#
# Uploading Condition:
# {
#   "resourceType": "Condition",
#   "clinicalStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#         "code": "active",
#         "display": "Active"
#       }
#     ]
#   },
#   "verificationStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#         "code": "confirmed",
#         "display": "Confirmed"
#       }
#     ]
#   },
#   "category": [
#     {
#       "coding": [
#         {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "problem-list-item",
#           "display": "Problem List Item"
#         }
#       ]
#     }
#   ],
#   "code": {
#     "text": "Ant Bite Allergy"
#   },
#   "subject": {
#     "reference": "Patient/0a8212cc-ad5e-40e0-b47f-14760116b0cc"
#   },
#   "onsetDateTime": "2013",
#   "recordedDate": "2020-06-24",
#   "asserter": {
#     "display": "Dr A Practitioner"
#   }
# }
# Created Patient: {'asserter': {'display': 'Dr A Practitioner'}, 'category': [{'coding': [{'code': 'problem-list-item', 'display': 'Problem List Item', 'system': 'http://terminology.hl7.org/CodeSystem/condition-category'}]}], 'clinicalStatus': {'coding': [{'code': 'active', 'display': 'Active', 'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical'}]}, 'code': {'text': 'Ant Bite Allergy'}, 'id': '1e81120e-3a05-44fb-8747-e85dd2b0dfbb', 'meta': {'lastUpdated': '2025-07-06T01:53:50.352064+00:00', 'versionId': 'MTc1MTc2NjgzMDM1MjA2NDAwMA'}, 'onsetDateTime': '2013', 'recordedDate': '2020-06-24', 'resourceType': 'Condition', 'subject': {'reference': 'Patient/0a8212cc-ad5e-40e0-b47f-14760116b0cc'}, 'verificationStatus': {'coding': [{'code': 'confirmed', 'display': 'Confirmed', 'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status'}]}}
#
# ```json
# {
#   "resourceType": "Condition",
#   "clinicalStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#         "code": "active",
#         "display": "Active"
#       }
#     ]
#   },
#   "verificationStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#         "code": "confirmed",
#         "display": "Confirmed"
#       }
#     ]
#   },
#   "category": [
#     {
#       "coding": [
#         {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "encounter-diagnosis",
#           "display": "Encounter Diagnosis"
#         }
#       ]
#     }
#   ],
#   "code": {
#     "text": "Cardiovasular Vascular Disease"
#   },
#   "subject": {
#     "reference": "Patient/GrahamANDREWS"
#   },
#   "recordedDate": "2020-06-24",
#   "asserter": {
#     "display": "Dr A Practitioner"
#   }
# }
# ```
#
# Uploading Condition:
# {
#   "resourceType": "Condition",
#   "clinicalStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#         "code": "active",
#         "display": "Active"
#       }
#     ]
#   },
#   "verificationStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#         "code": "confirmed",
#         "display": "Confirmed"
#       }
#     ]
#   },
#   "category": [
#     {
#       "coding": [
#         {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "encounter-diagnosis",
#           "display": "Encounter Diagnosis"
#         }
#       ]
#     }
#   ],
#   "code": {
#     "text": "Cardiovasular Vascular Disease"
#   },
#   "subject": {
#     "reference": "Patient/0a8212cc-ad5e-40e0-b47f-14760116b0cc"
#   },
#   "recordedDate": "2020-06-24",
#   "asserter": {
#     "display": "Dr A Practitioner"
#   }
# }
# Created Patient: {'asserter': {'display': 'Dr A Practitioner'}, 'category': [{'coding': [{'code': 'encounter-diagnosis', 'display': 'Encounter Diagnosis', 'system': 'http://terminology.hl7.org/CodeSystem/condition-category'}]}], 'clinicalStatus': {'coding': [{'code': 'active', 'display': 'Active', 'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical'}]}, 'code': {'text': 'Cardiovasular Vascular Disease'}, 'id': 'c434d4b4-1075-4028-a667-31bc6848aefc', 'meta': {'lastUpdated': '2025-07-06T01:53:50.440251+00:00', 'versionId': 'MTc1MTc2NjgzMDQ0MDI1MTAwMA'}, 'recordedDate': '2020-06-24', 'resourceType': 'Condition', 'subject': {'reference': 'Patient/0a8212cc-ad5e-40e0-b47f-14760116b0cc'}, 'verificationStatus': {'coding': [{'code': 'confirmed', 'display': 'Confirmed', 'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status'}]}}
#
# ```json
# {
#   "resourceType": "Condition",
#   "clinicalStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#         "code": "active",
#         "display": "Active"
#       }
#     ]
#   },
#   "verificationStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#         "code": "confirmed",
#         "display": "Confirmed"
#       }
#     ]
#   },
#   "category": [
#     {
#       "coding": [
#         {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "encounter-diagnosis",
#           "display": "Encounter Diagnosis"
#         }
#       ]
#     }
#   ],
#   "code": {
#     "text": "Obesity"
#   },
#   "subject": {
#     "reference": "Patient/GrahamANDREWS"
#   },
#   "recordedDate": "2020-06-24",
#   "asserter": {
#     "display": "Dr A Practitioner"
#   }
# }
# ```
# Uploading Condition:
# {
#   "resourceType": "Condition",
#   "clinicalStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-clinical",
#         "code": "active",
#         "display": "Active"
#       }
#     ]
#   },
#   "verificationStatus": {
#     "coding": [
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/condition-ver-status",
#         "code": "confirmed",
#         "display": "Confirmed"
#       }
#     ]
#   },
#   "category": [
#     {
#       "coding": [
#         {
#           "system": "http://terminology.hl7.org/CodeSystem/condition-category",
#           "code": "encounter-diagnosis",
#           "display": "Encounter Diagnosis"
#         }
#       ]
#     }
#   ],
#   "code": {
#     "text": "Obesity"
#   },
#   "subject": {
#     "reference": "Patient/0a8212cc-ad5e-40e0-b47f-14760116b0cc"
#   },
#   "recordedDate": "2020-06-24",
#   "asserter": {
#     "display": "Dr A Practitioner"
#   }
# }
# Created Patient: {'asserter': {'display': 'Dr A Practitioner'}, 'category': [{'coding': [{'code': 'encounter-diagnosis', 'display': 'Encounter Diagnosis', 'system': 'http://terminology.hl7.org/CodeSystem/condition-category'}]}], 'clinicalStatus': {'coding': [{'code': 'active', 'display': 'Active', 'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical'}]}, 'code': {'text': 'Obesity'}, 'id': '6c159b50-efcd-4789-916e-618b93203335', 'meta': {'lastUpdated': '2025-07-06T01:53:50.543810+00:00', 'versionId': 'MTc1MTc2NjgzMDU0MzgxMDAwMA'}, 'recordedDate': '2020-06-24', 'resourceType': 'Condition', 'subject': {'reference': 'Patient/0a8212cc-ad5e-40e0-b47f-14760116b0cc'}, 'verificationStatus': {'coding': [{'code': 'confirmed', 'display': 'Confirmed', 'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status'}]}}

# %%
print(careplan)
# Out:
# ```json
# {
#   "id": "careplan-graham-andrews",
#   "intent": "plan",
#   "status": "active",
#   "title": "CAREPLAN Graham ANDREWS",
#   "description": "Comprehensive care plan for Graham Andrews focusing on lifestyle, biomedical, pharmacological, cardiovascular, and obesity management.",
#   "created": "2020-06-24",
#   "period": {
#     "start": "2020-06-24",
#     "end": "2020-09-24"
#   },
#   "subject": {
#     "reference": "Patient/graham-andrews",
#     "display": "Graham ANDREWS"
#   },
#   "author": {
#     "display": "Dr A Practitioner"
#   },
#   "category": [
#     {
#       "text": "Lifestyle (General Health)"
#     },
#     {
#       "text": "Biomedical (General Health)"
#     },
#     {
#       "text": "Pharmacological (General Health)"
#     },
#     {
#       "text": "Cardiovasular Vascular Disease"
#     },
#     {
#       "text": "Obesity"
#     }
#   ],
#   "addresses": [
#     {
#       "display": "Ant Bite Allergy"
#     },
#     {
#       "display": "Obesity"
#     },
#     {
#       "display": "Cardiovascular Disease"
#     }
#   ],
#   "activity": [
#     {
#       "detail": {
#         "description": "Education on Condition: Educate patients regarding their role in optimally managing their condition.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Educate patients regarding their role in optimally managing their condition. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Know how to optimally monitor and manage your condition. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Weight Management: Your Ideal Target: BMI: Less than 25, Waist (Male): Less than 94cm.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for ALISON CAFE (Dietician), Exercise Physiologist, Dr A Practitioner (GP): Lifestyle modifications as advised by Dietician and Exercise Physiologist. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Maintain your weight/prevent weight gain by eating healthy and doing at least 30 minutes of physical activity on most days. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Healthy Eating: Advise eating according to Australian dietary guidelines, with attention to quantity and type of food.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for ALISON CAFE (Dietician), Dr A Practitioner (GP): Advice and education in developing a healthy eating plan. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Dietitian. Follow your personal healthy eating plan. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Physical Activity and Exercise: At least 30 minutes of moderate physical activity on most if not all days of the week (total ≥150 minutes/week).",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Exercise Physiologist, Dr A Practitioner (GP): Advice and education in developing a physical activity and exercise plan. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Exercise Pysiologist. Follow your personal activity / exercise plan. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Mobility, Balance and Flexibility: Advice on how to minimise the risk of falls and optimise mobility, balance and flexibility.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Exercise Physiologist, Dr A Practitioner (GP), Occupational Therapist, Osteopath, Physiotherapist: Advice on how to minimise the risk of falls and optimise mobility, balance and flexibility. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Exercise Physiologist. Follow your personal activity / exercise plan. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Mental and Emotional well-being: Review and consider referral if a psychological stress or issue has been identified.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Psychologist: Advise and monitor, Support groups / services, OT referral. Assess psychological impact. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Psychologist. Support Resources https://www.blackdoginstitute.org.au http://www.relationships nsw.org.au. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Assistance with daily living: Advice on how to optimise and preserve independence with home assistance including support group or links to community services.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Occupational Therapist, Registered Nurse (Aged Care): Advice on how to optimise and preserve independence with home assistance including support group or links to community services. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Occupational Therapist. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Alcohol Intake: Your Ideal Target: No more than 2 Standard drinks per day (Male).",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Drug and Alcohol Counsellor, Dr A Practitioner (GP), Registered Nurse (Medical Practice): Advice regarding safe alcohol intake. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: No more than 2 standard drinks per day for men and women and at least 2 alcohol free nights a week. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Smoking Cessation: Complete cessation.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Drug and Alcohol Counsellor, Dr A Practitioner (GP), Mental Health Worker: Advice on cessation of smoking / pharmacotherapy recommendations. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Book/attend appointment with (Hypnotherapist, Psychologist, Mental Health Worker). Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Substance Dependency: Advice regarding a substance dependency program.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Drug and Alcohol Counsellor, Dr A Practitioner (GP), Mental Health Worker: Advice regarding a substance dependency program. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with (Hypnotherapist, Psychologist, Mental Health Worker). Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Blood Checks: Regular routine bloods reviews.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Regular routine bloods. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Regular routine bloods."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Eye Checks: Eye review to monitor refractive errors, age-related cataract, glaucoma, age-related Macular degeneration, and diabetic retinopathy, optic nerve disorders or diabetic eye problems.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Opthalmologist, Optometrist: Eye review to monitor refractive errors, age-related cataract, glaucoma, age-related Macular degeneration, and diabetic retinopathy, optic nerve dis orders or diabetic eye problems. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Optometrist / Ophthalmologist. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Dental Health: Dental review to monitor early prevention and intervention.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dentist: Dental review to monitor early prevention and intervention. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Dentist. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Hearing Health: Detect hearing, balance, and related disorders. Provide options such as hearing aids, cochlear implants.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Audiologist: Detect hearing, balance, and related dis orders. Provide options such as hearing aids, cochlear implants. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Audiologist. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Skin Checks: Maintain skin integrity with early detection of suspicious lesions, removal as required. Regular skin checks.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dermatologist, Dr A Practitioner (GP): Maintain skin integrity with early detection of suspicious lesions, removal as required. Regular skin checks. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Dermatologist. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Routine Screening /Preventative: Monitor and screen health status. Cervical smear due: Mammogram due: Bowel screening (FOBT/Colons copy) due: Bone density due:",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Monitor and screen health status. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Health Assessments: Diabetic screen 40-49yo, Health assessment over 75yo.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP): Regular Health assessments. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Dr A Practitioner (GP): Diabetes assessment review. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Medication Education and Compliance: Educate patient about the importance of adhering to prescribed treatment and correct use of medications to minimise side effects.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Educate patient about the importance of adhering to pres cribed treatment and correct use of medications to minimise side effects. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Take medications as prescribed. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Medicines Review: Referral for medication review to understand the importance of adhering to prescribed treatment and correct use of medications to minimise side effects.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP): Referral for medication review to understand the importance of adhering to prescribed treatment and correct use of medications to minimise side effects. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment for a Medicines Review. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Immunisation: Ensure immunisations are up to date.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Ensure immunisations are up to date. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Cardiac Symptoms: Minimise ongoing cardiac symptoms. Assess severity and individualise treatment.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Cardiologist, Dr A Practitioner (GP): Minimise ongoing cardiac symptoms. Review: Every 3 months."
#         },
#         {
#           "text": "Task for Cardiologist, Dr A Practitioner (GP): Assess severity and individualise treatment. Review: Every 3 months."
#         },
#         {
#           "text": "Task for Patient: Take your medications daily. Report any side effects or worsening of symptoms. Review: Every 3 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Chest Pain: Develop an action plan on the use of anti-anginals and when to ring the ambulance.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Develop an action plan on the use of anti-anginals and when to ring the ambulance. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Follow your chest pain action plan. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Know how and when to call the ambulance. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Cardiovascular Risk Factors: Appropriate advice and care in modifying cardiovascular risk factors. Regularly assess lipids, smoking, nutrition, alcohol and physical activity Maintain BP.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Cardiologist, Dr A Practitioner (GP): Appropriate advice and care in modifying cardiovascular risk factors. Review: Every 3 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Medication (Cardiovascular): Manage the use of: antiplatelets, beta blockers, anticoagulants, statins and antihypertensives.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Cardiologist, Dr A Practitioner (GP): Manage the use of: antiplatelets, beta blockers, anticoagulants, statins and antihypertensives. Review: Every 3 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Stress: Reduce stress as much as possible. Consider referral.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Psychologist: Reduce stress as much as possible. Consider referral. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Reduce stress as much as possible. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Bio-Medical Blood Checks (Obesity): Bio-medical blood checks to observe improvements/issues. Cholesterol levels - Blood test, (LDL-C less than 2.0, HDL-C greater than 1.0) o HbA1c- blood test every 3 months, acceptable levels less than 53mmol/mol o Blood glucose levels - blood test, healthy between 6-8mmol/L fasting.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Cholesterol levels - Blood test, (LDL-C < 2.0, HDL-C > 1.0) o HbA1c- blood test every 3 months, acceptable levels < 53mmol/mol o Blood glucose levels - blood test, healthy between 6-8mmol/L fasting. Review: Every 6 months."
#         },
#         {
#           "text": "Task for ALISON CAFE (Dietician), Dr A Practitioner (GP), Registered Nurse (Medical Practice), Patient: Discuss how to optimally monitor and manage your weight loss with GP/ nurse. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Blood Pressure (Obesity): BP- to acceptable national target (less than 130). Your target: Less than 130/80.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): BP- to acceptable national target (less than 130). Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Cardiovascular Risk (Obesity): Appropriate advice and care in managing the cardiovascular system, including postural BP, central and peripheral vascular systems.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Appropriate advice and care in managing the cardiovascular system, including postural BP, central and peripheral vascular systems. Review: Every 6 months."
#         }
#       ]
#     }
#   ]
# }
# ```

# %%
fhir_careplan=func_extract_json(careplan)

fhir_careplan['subject']['reference']=f"Patient/{res['id']}"
fhir_careplan['resourceType']='CarePlan'
try:
    fhir_careplan.pop('id') 
except:
    s=''
rescp=upload_fhir_resource(fhir_careplan)
# Out:
# Uploading CarePlan:
# {
#   "intent": "plan",
#   "status": "active",
#   "title": "CAREPLAN Graham ANDREWS",
#   "description": "Comprehensive care plan for Graham Andrews focusing on lifestyle, biomedical, pharmacological, cardiovascular, and obesity management.",
#   "created": "2020-06-24",
#   "period": {
#     "start": "2020-06-24",
#     "end": "2020-09-24"
#   },
#   "subject": {
#     "reference": "Patient/0a8212cc-ad5e-40e0-b47f-14760116b0cc",
#     "display": "Graham ANDREWS"
#   },
#   "author": {
#     "display": "Dr A Practitioner"
#   },
#   "category": [
#     {
#       "text": "Lifestyle (General Health)"
#     },
#     {
#       "text": "Biomedical (General Health)"
#     },
#     {
#       "text": "Pharmacological (General Health)"
#     },
#     {
#       "text": "Cardiovasular Vascular Disease"
#     },
#     {
#       "text": "Obesity"
#     }
#   ],
#   "addresses": [
#     {
#       "display": "Ant Bite Allergy"
#     },
#     {
#       "display": "Obesity"
#     },
#     {
#       "display": "Cardiovascular Disease"
#     }
#   ],
#   "activity": [
#     {
#       "detail": {
#         "description": "Education on Condition: Educate patients regarding their role in optimally managing their condition.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Educate patients regarding their role in optimally managing their condition. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Know how to optimally monitor and manage your condition. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Weight Management: Your Ideal Target: BMI: Less than 25, Waist (Male): Less than 94cm.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for ALISON CAFE (Dietician), Exercise Physiologist, Dr A Practitioner (GP): Lifestyle modifications as advised by Dietician and Exercise Physiologist. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Maintain your weight/prevent weight gain by eating healthy and doing at least 30 minutes of physical activity on most days. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Healthy Eating: Advise eating according to Australian dietary guidelines, with attention to quantity and type of food.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for ALISON CAFE (Dietician), Dr A Practitioner (GP): Advice and education in developing a healthy eating plan. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Dietitian. Follow your personal healthy eating plan. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Physical Activity and Exercise: At least 30 minutes of moderate physical activity on most if not all days of the week (total \u2265150 minutes/week).",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Exercise Physiologist, Dr A Practitioner (GP): Advice and education in developing a physical activity and exercise plan. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Exercise Pysiologist. Follow your personal activity / exercise plan. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Mobility, Balance and Flexibility: Advice on how to minimise the risk of falls and optimise mobility, balance and flexibility.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Exercise Physiologist, Dr A Practitioner (GP), Occupational Therapist, Osteopath, Physiotherapist: Advice on how to minimise the risk of falls and optimise mobility, balance and flexibility. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Exercise Physiologist. Follow your personal activity / exercise plan. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Mental and Emotional well-being: Review and consider referral if a psychological stress or issue has been identified.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Psychologist: Advise and monitor, Support groups / services, OT referral. Assess psychological impact. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Psychologist. Support Resources https://www.blackdoginstitute.org.au http://www.relationships nsw.org.au. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Assistance with daily living: Advice on how to optimise and preserve independence with home assistance including support group or links to community services.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Occupational Therapist, Registered Nurse (Aged Care): Advice on how to optimise and preserve independence with home assistance including support group or links to community services. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Occupational Therapist. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Alcohol Intake: Your Ideal Target: No more than 2 Standard drinks per day (Male).",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Drug and Alcohol Counsellor, Dr A Practitioner (GP), Registered Nurse (Medical Practice): Advice regarding safe alcohol intake. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: No more than 2 standard drinks per day for men and women and at least 2 alcohol free nights a week. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Smoking Cessation: Complete cessation.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Drug and Alcohol Counsellor, Dr A Practitioner (GP), Mental Health Worker: Advice on cessation of smoking / pharmacotherapy recommendations. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Book/attend appointment with (Hypnotherapist, Psychologist, Mental Health Worker). Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Substance Dependency: Advice regarding a substance dependency program.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Drug and Alcohol Counsellor, Dr A Practitioner (GP), Mental Health Worker: Advice regarding a substance dependency program. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with (Hypnotherapist, Psychologist, Mental Health Worker). Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Blood Checks: Regular routine bloods reviews.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Regular routine bloods. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Regular routine bloods."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Eye Checks: Eye review to monitor refractive errors, age-related cataract, glaucoma, age-related Macular degeneration, and diabetic retinopathy, optic nerve disorders or diabetic eye problems.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Opthalmologist, Optometrist: Eye review to monitor refractive errors, age-related cataract, glaucoma, age-related Macular degeneration, and diabetic retinopathy, optic nerve dis orders or diabetic eye problems. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Optometrist / Ophthalmologist. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Dental Health: Dental review to monitor early prevention and intervention.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dentist: Dental review to monitor early prevention and intervention. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Dentist. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Hearing Health: Detect hearing, balance, and related disorders. Provide options such as hearing aids, cochlear implants.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Audiologist: Detect hearing, balance, and related dis orders. Provide options such as hearing aids, cochlear implants. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Audiologist. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Skin Checks: Maintain skin integrity with early detection of suspicious lesions, removal as required. Regular skin checks.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dermatologist, Dr A Practitioner (GP): Maintain skin integrity with early detection of suspicious lesions, removal as required. Regular skin checks. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment with Dermatologist. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Routine Screening /Preventative: Monitor and screen health status. Cervical smear due: Mammogram due: Bowel screening (FOBT/Colons copy) due: Bone density due:",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Monitor and screen health status. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Health Assessments: Diabetic screen 40-49yo, Health assessment over 75yo.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP): Regular Health assessments. Review: Every 12 months."
#         },
#         {
#           "text": "Task for Dr A Practitioner (GP): Diabetes assessment review. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Medication Education and Compliance: Educate patient about the importance of adhering to prescribed treatment and correct use of medications to minimise side effects.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Educate patient about the importance of adhering to pres cribed treatment and correct use of medications to minimise side effects. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Take medications as prescribed. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Medicines Review: Referral for medication review to understand the importance of adhering to prescribed treatment and correct use of medications to minimise side effects.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP): Referral for medication review to understand the importance of adhering to prescribed treatment and correct use of medications to minimise side effects. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Book attend appointment for a Medicines Review. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Immunisation: Ensure immunisations are up to date.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Ensure immunisations are up to date. Review: Every 12 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Cardiac Symptoms: Minimise ongoing cardiac symptoms. Assess severity and individualise treatment.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Cardiologist, Dr A Practitioner (GP): Minimise ongoing cardiac symptoms. Review: Every 3 months."
#         },
#         {
#           "text": "Task for Cardiologist, Dr A Practitioner (GP): Assess severity and individualise treatment. Review: Every 3 months."
#         },
#         {
#           "text": "Task for Patient: Take your medications daily. Report any side effects or worsening of symptoms. Review: Every 3 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Chest Pain: Develop an action plan on the use of anti-anginals and when to ring the ambulance.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Develop an action plan on the use of anti-anginals and when to ring the ambulance. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Follow your chest pain action plan. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Know how and when to call the ambulance. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Cardiovascular Risk Factors: Appropriate advice and care in modifying cardiovascular risk factors. Regularly assess lipids, smoking, nutrition, alcohol and physical activity Maintain BP.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Cardiologist, Dr A Practitioner (GP): Appropriate advice and care in modifying cardiovascular risk factors. Review: Every 3 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Medication (Cardiovascular): Manage the use of: antiplatelets, beta blockers, anticoagulants, statins and antihypertensives.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Cardiologist, Dr A Practitioner (GP): Manage the use of: antiplatelets, beta blockers, anticoagulants, statins and antihypertensives. Review: Every 3 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Stress: Reduce stress as much as possible. Consider referral.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Psychologist: Reduce stress as much as possible. Consider referral. Review: Every 6 months."
#         },
#         {
#           "text": "Task for Patient: Reduce stress as much as possible. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Bio-Medical Blood Checks (Obesity): Bio-medical blood checks to observe improvements/issues. Cholesterol levels - Blood test, (LDL-C less than 2.0, HDL-C greater than 1.0) o HbA1c- blood test every 3 months, acceptable levels less than 53mmol/mol o Blood glucose levels - blood test, healthy between 6-8mmol/L fasting.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Cholesterol levels - Blood test, (LDL-C < 2.0, HDL-C > 1.0) o HbA1c- blood test every 3 months, acceptable levels < 53mmol/mol o Blood glucose levels - blood test, healthy between 6-8mmol/L fasting. Review: Every 6 months."
#         },
#         {
#           "text": "Task for ALISON CAFE (Dietician), Dr A Practitioner (GP), Registered Nurse (Medical Practice), Patient: Discuss how to optimally monitor and manage your weight loss with GP/ nurse. Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Blood Pressure (Obesity): BP- to acceptable national target (less than 130). Your target: Less than 130/80.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): BP- to acceptable national target (less than 130). Review: Every 6 months."
#         }
#       ]
#     },
#     {
#       "detail": {
#         "description": "Cardiovascular Risk (Obesity): Appropriate advice and care in managing the cardiovascular system, including postural BP, central and peripheral vascular systems.",
#         "status": "in-progress"
#       },
#       "progress": [
#         {
#           "text": "Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Appropriate advice and care in managing the cardiovascular system, including postural BP, central and peripheral vascular systems. Review: Every 6 months."
#         }
#       ]
#     }
#   ],
#   "resourceType": "CarePlan"
# }
# Created Patient: {'activity': [{'detail': {'description': 'Education on Condition: Educate patients regarding their role in optimally managing their condition.', 'status': 'in-progress'}, 'progress': [{'text': 'Task for Dr A Practitioner (GP), Registered Nurse (Medical Practice): Educate patients regarding their role in optimally managing their condition. Review: Every 12 months.'}, {'text': 'Task for Patient: Know how to optimally monitor and manage your condition. Review: Every 12 months.'}]}, {'detail': {'description': 'Weight Management: Your Ideal Target: BMI: Less than 25, Waist (Male): Less than 94cm.', 'status': 'in-progress'}, 'progress': [{'text': 'Task for ALISON CAFE (Dietician), Exercise Physiologist, Dr A Practitioner (GP): Lifestyle modifications as advised by Dietician and Exercise Physiologist. Review: Every 6 months.'}, {'text': 'Task for Patient: Maintain your weight/prevent weight gain by eating healthy and doing at least 30 minutes of physical activity on most days. Review: Every 6 months.'}]}, {'detail': {'description': 'Healthy Eating: Advise eating according to Australian dietary guidelines, with attention to quantity and type of food.', 'status': 'in-progress'}, 'progress': [{'text': 'Task for ALISON CAFE (Dietician), Dr A Practitioner (GP): Advice and education in developing a healthy eating plan. Review: Every 6 months.'}, {'text': 'Task for Patient: Book attend appointment with Dietitian. Follow your personal healthy eating plan. Review: Every 6 months.'}]}, {'detail': {'description': 'Physical Activity and Exercise: At least 30 minutes of moderate physical activity on most if not all days of the week (total ≥150 minutes/week).', 'status': 'in-progress'}, 'progress': [{'text': 'Task for Exercise Physiologist, Dr A Practitioner (GP): Advice and education in developing a physical activity and exercise plan. Review: Every 6 months.'}, {'text': 'Task for Patient: Book attend appointment with Exercise Pysiologist. Follow your personal activity / exercise plan. Review: Every 6 months.'}]}, {'detail': {'description': 'Mobility, Balance and Flexibility: Advice on how to minimise the risk of falls and optimise mobility, balance and flexibility.', 'status': 'in-progress'}, 'progress': [{'text': 'Task for Exercise Physiologist, Dr A Practitioner (GP), Occupational Therapist, Osteopath, Physiotherapist: Advice on how to minimise the risk of falls and optimise mobility, balance and flexibility. Review: Every 6 months.'}, {'text': 'Task for Patient: Book attend appointment with Exercise Physiologist. Follow your personal activity / exercise plan. Review: Every 6 months.'}]}, {'detail': {'description': 'Mental and Emotional well-being: Review and consider referral if a psychological stress or issue has been identified.', 'status': 'in-progress'}, 'progress': [{'text': 'Task for Dr A Practitioner (GP), Psychologist: Advise and monitor, Support groups / services, OT referral. Assess psychological impact. Review: Every 6 months.'}, {'text': 'Task for Patient: Book attend appointment with Psychologist. Support Resources https://www.blackdoginstitute.org.au http://www.relationships nsw.org.au. Review: Every 6 months.'}]}, {'detail': {'description': 'Assistance with daily living: Advice on how to optimise and preserve independence with home assistance including support group or links to community services.', 'status': 'in-progress'}, 'progress': [{'text': 'Task for Dr A Practitioner (GP), Occupational Therapist, Registered Nurse (Aged Care): Advice on how to optimise and preserve independence with home assistance including support group or links to community services. Review: Every 6 months.'}, {'text': 'Task for Patient: Book attend appointment with Occupational Therapist. Review: Every 6 months.'}]}, {'detail': {'description': 'Alcohol Intake: Your Ideal Target: No more than 2 Standard drinks per day (Male).', 'status': 'in-progress'}, 'progress': [{'text': 'Task for Drug and Alcohol Counsellor, Dr A Practitioner (GP) ...
