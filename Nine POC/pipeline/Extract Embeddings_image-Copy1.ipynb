# %%
#set project info
PROJECT = !gcloud config get-value project
PROJECT_ID = PROJECT[0]
REGION ='us-cental1'

# %%
import urllib.request
url = "http://metadata.google.internal/computeMetadata/v1/project/project-id"
req = urllib.request.Request(url)
req.add_header("Metadata-Flavor", "Google")
project_id = urllib.request.urlopen(req).read().decode()

# %%
from google.cloud import storage


def list_blobs(bucket_name):
    """Lists all the blobs in the bucket."""
    # bucket_name = "your-bucket-name"
    paths=[]
    names=[]
    storage_client = storage.Client()

    # Note: Client.list_blobs requires at least package version 1.17.0.
    blobs = storage_client.list_blobs(bucket_name,match_glob=["**/*.png"])
 
    # Note: The call returns a response only when the iterator is consumed.
    for blob in blobs:    
        paths.append('gs://' + blob.id[:-(len(str(blob.generation)) + 1)])
        names.append(blob.name)
    return paths,names

# %%
image_paths,image_names=list_blobs('raw_nine_files')

# %% [markdown]
# ### Define function to detect explicit images
#
# enable clound vision api before running this bit

# %% [markdown]
# ### Defining encoding functions
# Create an EmbeddingPredictionClient which encapsulates the logic to call the embedding API.

# %%
import base64
import time
import typing
import copy
from typing import List, Optional

from google.cloud import aiplatform
from google.protobuf import struct_pb2

#libraries to generate image summaries
from vertexai.vision_models import MultiModalEmbeddingModel
from vertexai.language_models import TextEmbeddingModel
from vertexai.vision_models import Image as vision_model_Image
from vertexai.vision_models import MultiModalEmbeddingModel
from vertexai.preview.generative_models import (
    Content,
    GenerationConfig,
    GenerationResponse,
    GenerativeModel,
    Image,
    Part,
    HarmBlockThreshold,
    HarmCategory,
)

text_embedding_model = TextEmbeddingModel.from_pretrained("textembedding-gecko@latest")
#multimodal_embedding_model = MultiModalEmbeddingModel.from_pretrained(
 #   "multimodalembedding@001"
#)


class EmbeddingResponse(typing.NamedTuple):
    text_embedding: typing.Sequence[float]
    image_embedding: typing.Sequence[float]


import requests
def get_public_url_from_gcs(gcs_uri: str) -> str:
    return gcs_uri.replace("gs://", "https://storage.googleapis.com/").replace(
        " ", "%20"
    )

def load_image_bytes(image_uri: str) -> bytes:
    """Load image bytes from a remote or local URI."""
    image_bytes = None
    image_uri= get_public_url_from_gcs(image_uri)
    if image_uri.startswith("http://") or image_uri.startswith("https://"):
        response = requests.get(image_uri, stream=True)
        if response.status_code == 200:
            image_bytes = response.content
    else:
        image_bytes = open(image_uri, "rb").read()
    return image_bytes


class EmbeddingPredictionClient:
    """Wrapper around Prediction Service Client."""

    def __init__(
        self,
        project: str,
        location: str = "us-central1",
        api_regional_endpoint: str = "us-central1-aiplatform.googleapis.com",
    ):
        client_options = {"api_endpoint": api_regional_endpoint}
        # Initialize client that will be used to create and send requests.
        # This client only needs to be created once, and can be reused for multiple requests.
        self.client = aiplatform.gapic.PredictionServiceClient(
            client_options=client_options
        )
        self.location = location
        self.project = project

    def get_embedding(self, text: str = None, image_file: str = None):
        if not text and not image_file:
            raise ValueError("At least one of text or image_file must be specified.")

        # Load image file
        image_bytes = None
        if image_file:
            if not (image_file.startswith("gs://")): 
                image_bytes = load_image_bytes(image_file)

        instance = struct_pb2.Struct()
        if text:
            instance.fields["text"].string_value = text

        if image_bytes:
            encoded_content = base64.b64encode(image_bytes).decode("utf-8")
            image_struct = instance.fields["image"].struct_value
            image_struct.fields["bytesBase64Encoded"].string_value = encoded_content

        if image_file:
            if (image_file.startswith("gs://")): 
                  instance["image"] = {
                        "gcsUri": image_file  # pylint: disable=protected-access
                    }       
        
        instances = [instance]
        
        endpoint = (
           f"projects/{self.project}/locations/{self.location}"
           "/publishers/google/models/multimodalembedding@001"
        )
        response = self.client.predict(endpoint=endpoint, instances=instances)
        text_embedding = None
        if text:
            text_emb_value = response.predictions[0]["textEmbedding"]
            text_embedding = [v for v in text_emb_value]

        image_embedding = None
        if image_bytes or image_file:
            image_emb_value = response.predictions[0]["imageEmbedding"]
            image_embedding = [v for v in image_emb_value]

        return EmbeddingResponse(
            text_embedding=text_embedding, image_embedding=image_embedding
        )

    def get_image_summarycontent(self, text: str = None, image_file: str = None):
        
        generative_multimodal_model= GenerativeModel("gemini-pro-vision")
        
        image_description_prompt="""You are an assistant tasked with summarizing images for retrieval. \
        These summaries will be embedded and used to retrieve the raw image. \
        Give a concise summary of the image that is well optimized for retrieval.\
        If there is a famous person like politician, celebrity or athlete, indicate their name and describe what they are famous for.\
        If you are not sure about any info, please do not make it up."""
        
        generation_config= GenerationConfig(temperature=0.2, max_output_tokens=2048) 
        
        safety_settings=  {
        HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
        }
        stream=True
        
        # Load the saved image as a Gemini Image Object
        #image_for_gemini= Image.load_from_file(image_file)
        image_for_gemini = Part.from_uri(image_file, "image/jpeg")

        model_input=[image_description_prompt, image_for_gemini]
        
        response = generative_multimodal_model.generate_content(
        model_input,
        generation_config=generation_config,
        stream=stream,
        safety_settings=safety_settings, )
        
        
        response_list = []

        for chunk in response:
            try:
                response_list.append(chunk.text)
            except Exception as e:
                print(
                    "Exception occurred while calling gemini. Something is wrong. Lower the safety thresholds [safety_settings: BLOCK_NONE ] if not already done. -----",
                    e,
                )
                response_list.append("Exception occurred")
                continue
        response = "".join(response_list)
 
        return response

    def get_summarycontent_embedding_from_text_embedding_model(self, text: str, return_array: Optional[bool] = False,) -> list:
        """
        Generates a numerical text embedding from a provided text input using a text embedding model.

        Args:
            text: The input text string to be embedded.
            return_array: If True, returns the embedding as a NumPy array.
                          If False, returns the embedding as a list. (Default: False)

        Returns:
            list or numpy.ndarray: A 768-dimensional vector representation of the input text.
                                   The format (list or NumPy array) depends on the
                                   value of the 'return_array' parameter.
        """

        #the given text is maximum 2048 token. If more, it has to be chunked.
        embeddings = text_embedding_model.get_embeddings([text])
        text_embedding = [embedding.values for embedding in embeddings][0]

        if return_array:
            text_embedding = np.fromiter(text_embedding, dtype=float)

        # returns 768 dimensional array
        return EmbeddingResponse(
            text_embedding=text_embedding, image_embedding=None
        )

# %% [markdown]
# ### Create helper functions to process data in batches
# Datasets can be large, so it's recommended to load a batch of data at a time into memory using a generator.

# %%
import time
from concurrent.futures import ThreadPoolExecutor
from typing import Callable, Generator, List

from tqdm.auto import tqdm

#Number of API calls per second
API_IMAGES_PER_SECOND = 2

def generate_batches(
    inputs: List[str], batch_size: int
) -> Generator[List[str], None, None]:
    """
    Generator function that takes a list of strings and a batch size, and yields batches of the specified size.
    """

    for i in range(0, len(inputs), batch_size):
        yield inputs[i : i + batch_size]



def encode_to_embeddings_chunked(
    process_function: Callable[[List[str]], List[Optional[List[float]]]],
    items: List[str],
    batch_size: int = 1,
) -> List[Optional[List[float]]]:
    """
    Function that encodes a list of strings into embeddings using a process function.
    It takes a list of strings and returns a list of optional lists of floats.
    The data is processed in chunks to prevent out-of-memory errors.
    """

    embeddings_list: List[Optional[List[float]]] = []

    # Prepare the batches using a generator
    batches = generate_batches(items, batch_size)

    seconds_per_job = batch_size / API_IMAGES_PER_SECOND

    with ThreadPoolExecutor() as executor:
        futures = []
        for batch in tqdm(batches, total=len(items) // batch_size, position=0):
            futures.append(executor.submit(process_function, batch))
            time.sleep(seconds_per_job)

        for future in futures:
            embeddings_list.extend(future.result())
    return embeddings_list

# %% [markdown]
# ### Create functions that wrap embedding functions in try-except and retry logic
# This particular embedding model can only process 1 image at a time, so inputs are validated to be equal to a length of 1.

# %%
import copy
from typing import List, Optional

import numpy as np
import requests
from tenacity import retry, stop_after_attempt

client = EmbeddingPredictionClient(project=PROJECT_ID)


# Use a retry handler in case of failure
@retry(reraise=True, stop=stop_after_attempt(3))
def encode_texts_to_embeddings_with_retry(text: List[str]) -> List[List[float]]:
    assert len(text) == 1

    try:
        return [client.get_embedding(text=text[0], image_file=None).text_embedding]
    except Exception:
        raise RuntimeError("Error getting embedding.")


def encode_texts_to_embeddings(text: List[str]) -> List[Optional[List[float]]]:
    try:
        return encode_texts_to_embeddings_with_retry(text=text)
    except Exception:
        return [None for _ in range(len(text))]


@retry(reraise=True, stop=stop_after_attempt(3))
def encode_images_to_embeddings_with_retry(image_uris: List[str]) -> List[List[float]]:
    assert len(image_uris) == 1

    try:
        return [
            client.get_embedding(text=None, image_file=image_uris[0]).image_embedding
        ]
    except Exception as ex:
        print(ex)
        raise RuntimeError("Error getting embedding for image.")


def encode_images_to_embeddings(image_uris: List[str]) -> List[Optional[List[float]]]:
    try:
        return encode_images_to_embeddings_with_retry(image_uris=image_uris)
    except Exception as ex:
        print(ex)
        return [None for _ in range(len(image_uris))]
    

@retry(reraise=True, stop=stop_after_attempt(3))
def encode_images_to_summarycontent_with_retry(image_uris: List[str]) -> List[List[float]]:
    assert len(image_uris) == 1

    try:
        return [
            client.get_image_summarycontent(text=None, image_file=image_uris[0])
        ]
    except Exception as ex:
        print(ex)
        raise RuntimeError("Error getting summaries.")


def encode_images_to_summarycontent(image_uris: List[str]) -> List[Optional[List[float]]]:
    try:
        return encode_images_to_summarycontent_with_retry(image_uris=image_uris)
    except Exception as ex:
        print(ex)
        return [None for _ in range(len(image_uris))]
    
    
# Use a retry handler in case of failure
@retry(reraise=True, stop=stop_after_attempt(3))
def encode_summarycontent_to_embeddings_with_retry(text: List[str]) -> List[List[float]]:
    assert len(text) == 1

    try:
        return [client.get_summarycontent_embedding_from_text_embedding_model(text=text[0]).text_embedding]
    except Exception:
        raise RuntimeError("Error getting embedding for summary content.")


def encode_summarycontent_to_embeddings(text: List[str]) -> List[Optional[List[float]]]:
    try:
        return encode_summarycontent_to_embeddings_with_retry(text=text)
    except Exception:
        return [None for _ in range(len(text))]

# %% [markdown]
# ### Create and save the embeddings in JSONL format
# The data must be formatted in JSONL format, which means each embedding dictionary is written as an individual JSON object on its own line.
#
# See more information in the docs at Input data format and structure.
#
# Run the following code in the next available cells, to create a temporary file to store embeddings in JSON format.

# %%
import tempfile, shutil

# Create temporary file to write embeddings to
embeddings_file = tempfile.NamedTemporaryFile(suffix=".json", delete=False)

# Create temporary file to write summaries to
summaries_file = tempfile.NamedTemporaryFile(suffix=".json", delete=False)

# %% [markdown]
# ### embedding file

# %%
import json

BATCH_SIZE = 1# this can be changed

with open(embeddings_file.name, "a") as ef, open(summaries_file.name, "a") as sf:
     for i in tqdm(range(0, len(image_names), BATCH_SIZE)):#len(image_names)
        image_names_chunk = image_names[i : i + BATCH_SIZE]
        image_paths_chunk = image_paths[i : i + BATCH_SIZE]
        embeddings=[]
        image_summaries=[]
        #comment to prevent extra costs
        #********************************
        embeddings = encode_to_embeddings_chunked(
            process_function=encode_images_to_embeddings, items=image_paths_chunk
        )
        #embeddings=[[1,2],[1,2]]
        #********************************

        #comment to prevent extra costs
        #********************************
        summaries = encode_to_embeddings_chunked(
            process_function=encode_images_to_summarycontent, items=image_paths_chunk
           )
        #summaries=['1'+str(i),'2'+str(i)]
        #********************************
        #summaries=[' The image shows three people: Joe Biden, a young girl, and Hunter Biden. Joe Biden is smiling and wearing a dark suit. The young girl is smiling and wearing a white dress. Hunter Biden is smiling and wearing a dark suit. The background is a photo of the White House.','this is test']
   
        #comment to prevent extra costs
        #********************************
        summaries_embeddings = encode_to_embeddings_chunked(
             process_function=encode_summarycontent_to_embeddings, items=summaries
        )
        #summaries_embeddings=[[1,2],[1,2,3]]
        
        #********************************
        
        #print(embeddings)
        #print('-----')
        print(summaries)
        #print('-----')
        #print(summaries_embeddings)
        # Append to file
        embeddings_formatted = [
            json.dumps(
                {
                    "id": str(id),
                    "embedding": [str(value) for value in embedding],
                }
            )
            + "\n"
            for id, embedding in zip(image_names_chunk, embeddings)
            if embedding is not None
        ]
        ef.writelines(embeddings_formatted)
        
        
        summaries_formatted = [
            json.dumps(
                {
                    "id": str(id),
                    "image path": image_path,
                    "summary":  summary,
                    "summary embedding": [str(value) for value in summaries_embedding],
                    "image embedding": [str(value) for value in embedding],
                }
            )
            + "\n"
            for id, summary,summaries_embedding,embedding,image_path in zip(image_names_chunk, summaries,summaries_embeddings,embeddings,image_paths_chunk)
            if summaries is not None
        ]
        sf.writelines(summaries_formatted)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# predictions {
#   struct_value {
#     fields {
#       key: "imageEmbedding"
#       value {
#         list_value {
#           values {
#             number_value: -0.00444012508
#           }
#           values {
#             number_value: 0.0210337229
#           }
#           values {
#             number_value: -0.017365694
#           }
#           values {
#             number_value: 0.00955259241
#           }
#           values {
#             number_value: -0.0127423927
#           }
#           values {
#             number_value: 0.030475162
#           }
#           values {
#             number_value: -0.00220635254
#           }
#           values {
#             number_value: 0.0184931103
#           }
#           values {
#             number_value: -0.00321653555
#           }
#           values {
#             number_value: 0.00739332289
#           }
#           values {
#             number_value: 0.0259710141
#           }
#           values {
#             number_value: -0.00304827583
#           }
#           values {
#             number_value: -0.00779922027
#           }
#           values {
#             number_value: -0.050977286
#           }
#           values {
#             number_value: -0.00216399063
#           }
#           values {
#             number_value: -0.0196345337
#           }
#           values {
#             number_value: -0.00187972118
#           }
#           values {
#             number_value: -0.0168311186
#           }
#           values {
#             number_value: -0.0543366075
#           }
#           values {
#             number_value: -0.0100784246
#           }
#           values {
#             number_value: -0.120106056
#           }
#           values {
#             number_value: -0.0243414957
#           }
#           values {
#             number_value: 0.00445964932
#           }
#           values {
#             number_value: -0.0144563252
#           }
#           values {
#             number_value: -0.0106951613
#           }
#           values {
#             number_value: 0.0104207005
#           }
#           values {
#             number_value: -0.0139832078
#           }
#           values {
#             number_value: 0.0142496377
#           }
#           values {
#             number_value: -0.0521039516
#           }
#           values {
#             number_value: 0.00449051149
#           }
#           values {
#             number_value: 0.028252434
#           }
#           values {
#             number_value: 0.0185930692
#           }
#           values {
#             number_value: 0.0254553799
#           }
#           values {
#             number_value: -0.0252815206
#           }
#           values {
#             number_value: -0.00611474551
#           }
#           values {
#             number_value: -0.0356585905
#           }
#           values {
#             number_value: -0.00605991576
#           }
#           values {
#             number_value: -0.000550621888
#           }
#           values {
#             number_value: -0.0113004018
#           }
#           values {
#             number_value: 0.0223962385
#           }
#           values {
#             number_value: 0.0310288891
#           }
#           values {
#             number_value: -0.0261098072
#           }
#           values {
#             number_value: 0.016297305
#           }
#           values {
#             number_value: 0.0430403315
#           }
#           values {
#             number_value: 0.0175702199
#           }
#           values {
#             number_value: 0.00855031237
#           }
#           values {
#             number_value: 0.019427022
#           }
#           values {
#             number_value: -0.0293029975
#           }
#           values {
#             number_value: -0.0249497965
#           }
#           values {
#             number_value: 0.00355830882
#           }
#           values {
#             number_value: 0.00582782319
#           }
#           values {
#             number_value: -0.0256010871
#           }
#           values {
#             number_value: -0.00414903508
#           }
#           values {
#             number_value: -0.00844268501
#           }
#           values {
#             number_value: 0.00565122906
#           }
#           values {
#             number_value: 0.015745284
#           }
#           values {
#             number_value: -0.005740094
#           }
#           values {
#             number_value: 0.0100543881
#           }
#           values {
#             number_value: 0.0139195919
#           }
#           values {
#             number_value: 5.97665348e-05
#           }
#           values {
#             number_value: -0.0309453737
#           }
#           values {
#             number_value: -0.0500134565
#           }
#           values {
#             number_value: -0.0107547613
#           }
#           values {
#             number_value: 0.0056345542
#           }
#           values {
#             number_value: 0.0152878109
#           }
#           values {
#             number_value: 0.0228429139
#           }
#           values {
#             number_value: -0.0126174241
#           }
#           values {
#             number_value: -0.00577305816
#           }
#           values {
#             number_value: 0.057631854
#           }
#           values {
#             number_value: -0.00990504213
#           }
#           values {
#             number_value: -0.0102254571
#           }
#           values {
#             number_value: -0.000656741031
#           }
#           values {
#             number_value: 0.0158246234
#           }
#           values {
#             number_value: 0.0122116432
#           }
#           values {
#             number_value: 0.000499555084
#           }
#           values {
#             number_value: -0.015180842
#           }
#           values {
#             number_value: -0.0506469123
#           }
#           values {
#             number_value: 0.0221314039
#           }
#           values {
#             number_value: -0.0386892557
#           }
#           values {
#             number_value: 0.0202692226
#           }
#           values {
#             number_value: 0.034621641
#           }
#           values {
#             number_value: 0.00256156642
#           }
#           values {
#             number_value: -0.0089163715
#           }
#           values {
#             number_value: -0.0143991867
#           }
#           values {
#             number_value: -0.00695866067
#           }
#           values {
#             number_value: -0.00663895765
#           }
#           values {
#             number_value: -0.0304454807
#           }
#           values {
#             number_value: -0.0156729128
#           }
#           values {
#             number_value: 0.00420985138
#           }
#           values {
#             number_value: -0.0586693063
#           }
#           values {
#             number_value: 0.00410887599
#           }
#           values {
#             number_value: 0.0271244571
#           }
#           values {
#             number_value: -0.0138416216
#           }
#           values {
#             number_value: -0.15936099
#           }
#           values {
#             number_value: 0.0203834027
#           }
#           values {
#             number_value: -0.00161394849
#           }
#           values {
#             number_value: -0.00562796602
#           }
#           values {
#             number_value: 0.0154480813
#           }
#           values {
#             number_value: -0.0111940512
#           }
#           values {
#             number_value: 0.00067317381
#           }
#           values {
#             number_value: 0.0150161823
#           }
#           values {
#             number_value: -0.00813828409
#           }
#           values {
#             number_value: 0.00957368594
#           }
#           values {
#             number_value: 0.0230095461
#           }
#           values {
#             number_value: 0.0173278227
#           }
#           values {
#             number_value: -0.0692076534
#           }
#           values {
#             number_value: 0.0059865457
#           }
#           values {
#             number_value: -0.0122644836
#           }
#           values {
#             number_value: -0.000921546132
#           }
#           values {
#             number_value: 0.00873366371
#           }
#           values {
#             number_value: -0.0174920075
#           }
#           values {
#             number_value: -0.0218976103
#           }
#           values {
#             number_value: -0.0138168316
#           }
#           values {
#             number_value: 0.00012235294
#           }
#           values {
#             number_value: -0.0119464993
#           }
#           values {
#             number_value: 0.00444180425
#           }
#           values {
#             number_value: 0.012896711
#           }
#           values {
#             number_value: -0.0244085789
#           }
#           values {
#             number_value: -0.00547057809
#           }
#           values {
#             number_value: -0.0390717871
#           }
#           values {
#             number_value: 0.00984387379
#           }
#           values {
#             number_value: -0.0839250758
#           }
#           values {
#             number_value: -0.0039052607
#           }
#           values {
#             number_value: 0.010645424
#           }
#           values {
#             number_value: 0.00403302116
#           }
#           values {
#             number_value: -0.068635568
#           }
#           values {
#             number_value: -0.0730247945
#           }
#           values {
#             number_value: -0.0321497694
#           }
#           values {
#             number_value: 0.0306086428
#           }
#           values {
#             number_value: 0.00282524526
#           }
#           values {
#             number_value: -0.00789668504
#           }
#           values {
#             number_value: 0.0471496843
#           }
#           values {
#             number_value: 0.0032123439
#           }
#           values {
#             number_value: 0.00807904545
#           }
#           values {
#             number_value: 0.0568375215
#           }
#           values {
#             number_value: -0.0125516597
#           }
#           values {
#             number_value: -0.00767103024
#           }
#           values {
#             number_value: -0.0525377281
#           }
#           values {
#             number_value: 0.04445244
#           }
#           values {
#             number_value: 0.0453907065
#           }
#           values {
#             number_value: 0.000527359371
#           }
#           values {
#             number_value: -0.00329903164
#           }
#           values {
#             number_value: 0.0286223739
#           }
#           values {
#             number_value: 0.0040852488
#           }
#           values {
#             number_value: -0.00727701746
#           }
#           values {
#             number_value: 0.023145549
#           }
#           values {
#             number_value: -0.014667714
#           }
#           values {
#             number_value: -0.0149145871
#           }
#           values {
#             number_value: -0.0308373123
#           }
#           values {
#             number_value: -0.00979836285
#           }
#           values {
#             number_value: 0.0714283735
#           }
#           values {
#             number_value: 0.058209192
#           }
#           values {
#             number_value: -0.0268710516
#           }
#           values {
#             number_value: -0.00671682181
#           }
#           values {
#             number_value: 0.00291648321
#           }
#           values {
#             number_value: -0.000204012176
#           }
#           values {
#             number_value: -0.0180397835
#           }
#           values {
#             number_value: 0.0101267816
#           }
#           values {
#             number_value: 0.00611936301
#           }
#           values {
#             number_value: -0.0148278456
#           }
#           values {
#             number_value: -0.0173990522
#           }
#           values {
#             number_value: 0.00415693223
#           }
#           values {
#             number_value: 0.00517000258
#           }
#           values {
#             number_value: 0.018526921
#           }
#           values {
#             number_value: 0.00585337915
#           }
#           values {
#             number_value: -0.0374452434
#           }
#           values {
#             number_value: -0.00631837966
#           }
#           values {
#             number_value: 0.0183791183
#           }
#           values {
#             number_value: -0.0194409639
#           }
#           values {
#             number_value: 0.0149781732
#           }
#           values {
#             number_value: 0.0142469928
#           }
#           values {
#             number_value: 0.0393047929
#           }
#           values {
#             number_value: 0.0222362243
#           }
#           values {
#             number_value: -0.0239165146
#           }
#           values {
#             number_value: -0.0234788433
#           }
#           values {
#             number_value: -0.00090113125
#           }
#           values {
#             number_value: 0.0155002121
#           }
#           values {
#             number_value: -0.00933643058
#           }
#           values {
#             number_value: -0.0283039771
#           }
#           values {
#             number_value: -0.0260372609
#           }
#           values {
#             number_value: 0.00348051
#           }
#           values {
#             number_value: -0.0144894095
#           }
#           values {
#             number_value: 0.00707418798
#           }
#           values {
#             number_value: -0.00462707411
#           }
#           values {
#             number_value: -0.0166963302
#           }
#           values {
#             number_value: 0.0102562644
#           }
#           values {
#             number_value: 0.0290883295
#           }
#           values {
#             number_value: 0.00394620607
#           }
#           values {
#             number_value: 0.0168204736
#           }
#           values {
#             number_value: 0.0138228461
#           }
#           values {
#             number_value: -0.0120806182
#           }
#           values {
#             number_value: -0.019039521
#           }
#           values {
#             number_value: 0.00322809652
#           }
#           values {
#             number_value: -0.00788892
#           }
#           values {
#             number_value: -0.023262227
#           }
#           values {
#             number_value: 0.0298531856
#           }
#           values {
#             number_value: 0.0189847779
#           }
#           values {
#             number_value: -0.0517971478
#           }
#           values {
#             number_value: 0.00403931318
#           }
#           values {
#             number_value: -0.000163811972
#           }
#           values {
#             number_value: 0.0223089047
#           }
#           values {
#             number_value: 0.00316402433
#           }
#           values {
#             number_value: -0.000639383856
#           }
#           values {
#             number_value: -0.00129065965
#           }
#           values {
#             number_value: -0.0399788171
#           }
#           values {
#             number_value: -0.00761862798
#           }
#           values {
#             number_value: -0.0206231847
#           }
#           values {
#             number_value: -0.00318652904
#           }
#           values {
#             number_value: -0.010760041
#           }
#           values {
#             number_value: -0.000110583649
#           }
#           values {
#             number_value: 0.00872463733
#           }
#           values {
#             number_value: 0.00645321514
#           }
#           values {
#             number_value: 0.0139524499
#           }
#           values {
#             number_value: 0.056108743
#           }
#           values {
#             number_value: -0.0253665522
#           }
#           values {
#             number_value: 0.00160112558
#           }
#           values {
#             number_value: -0.0258355252
#           }
#           values {
#             number_value: 0.00244109
#           }
#           values {
#             number_value: 0.0154369818
#           }
#           values {
#             number_value: 0.0022636971
#           }
#           values {
#             number_value: 0.00260086684
#           }
#           values {
#             number_value: -0.0156788342
#           }
#           values {
#             number_value: -0.0408377312
#           }
#           values {
#             number_value: -0.0243109241
#           }
#           values {
#             number_value: -0.0114603173
#           }
#           values {
#             number_value: -0.0374341495
#           }
#           values {
#             number_value: -0.0131770298
#           }
#           values {
#             number_value: 0.0387151316
#           }
#           values {
#             number_value: -0.0484431908
#           }
#           values {
#             number_value: -0.0595079362
#           }
#           values {
#             number_value: -0.0258904118
#           }
#           values {
#             number_value: -0.0165969692
#           }
#           values {
#             number_value: -0.0293628331
#           }
#           values {
#             number_value: -0.0227633025
#           }
#           values {
#             number_value: -0.0247919299
#           }
#           values {
#             number_value: -0.0222011097
#           }
#           values {
#             number_value: -0.0125023369
#           }
#           values {
#             number_value: 0.004861956
#           }
#           values {
#             number_value: -0.0212235898
#           }
#           values {
#             number_value: -0.022166213
#           }
#           values {
#             number_value: -0.0142503539
#           }
#           values {
#             number_value: -0.00891704578
#           }
#           values {
#             number_value: -0.0327361301
#           }
#           values {
#             number_value: 0.0275592562
#           }
#           values {
#             number_value: -0.0098552946
#           }
#           values {
#             number_value: -0.0364228301
#           }
#           values {
#             number_value: -0.0215481408
#           }
#           values {
#             number_value: 0.00909130741
#           }
#           values {
#             number_value: 0.0124221556
#           }
#           values {
#             number_value: -0.0148393707
#           }
#           values {
#             number_value: 0.0124513861
#           }
#           values {
#             number_value: 0.0313188434
#           }
#           values {
#             number_value: -0.00200241967
#           }
#           values {
#             number_value: 0.00181984843
#           }
#           values {
#             number_value: -0.0231111776
#           }
#           values {
#             number_value: 0.00671835849
#           }
#           values {
#             number_value: -0.00653637806
#           }
#           values {
#             number_value: -0.0113846688
#           }
#           values {
#             number_value: -0.00540738273
#           }
#           values {
#             number_value: -0.0350453146
#           }
#           values {
#             number_value: -0.00170942966
#           }
#           values {
#             number_value: 0.00190540741
#           }
#           values {
#             number_value: -0.0159656908
#           }
#           values {
#             number_value: -0.018727202
#           }
#           values {
#             number_value: -0.0184545908
#           }
#           values {
#             number_value: 0.0133503359
#           }
#           values {
#             number_value: 0.0254643243
#           }
#           values {
#             number_value: 0.0310911816
#           }
#           values {
#             number_value: 0.0373760611
#           }
#           values {
#             number_value: -0.00974333193
#           }
#           values {
#             number_value: -0.00278462912
#           }
#           values {
#             number_value: 0.0236041844
#           }
#           values {
#             number_value: -0.0302026905
#           }
#           values {
#             number_value: 0.00616716594
#           }
#           values {
#             number_value: -0.00102866685
#           }
#           values {
#             number_value: 0.0353315361
#           }
#           values {
#             number_value: 0.0241625886
#           }
#           values {
#             number_value: 0.00346071762
#           }
#           values {
#             number_value: 0.0213336181
#           }
#           values {
#             number_value: 0.0976834893
#           }
#           values {
#             number_value: -0.0463353172
#           }
#           values {
#             number_value: -0.0249365475
#           }
#           values {
#             number_value: -0.0462679975
#           }
#           values {
#             number_value: -0.00392915728
#           }
#           values {
#             number_value: 0.0222089197
#           }
#           values {
#             number_value: -0.0148679884
#           }
#           values {
#             number_value: -0.0623106509
#           }
#           values {
#             number_value: -0.0246338472
#           }
#           values {
#             number_value: 0.00732767908
#           }
#           values {
#             number_value: 0.00274169934
#           }
#           values {
#             number_value: -0.00310873589
#           }
#           values {
#             number_value: 0.0272394661
#           }
#           values {
#             number_value: -0.0435831659
#           }
#           values {
#             number_value: 0.0125940619
#           }
#           values {
#             number_value: 0.00703735929
#           }
#           values {
#             number_value: -0.0333507322
#           }
#           values {
#             number_value: -0.0034621486
#           }
#           values {
#             number_value: 0.00719737
#           }
#           values {
#             number_value: 0.0031572436
#           }
#           values {
#             number_value: -0.0208545662
#           }
#           values {
#             number_value: 0.0101242699
#           }
#           values {
#             number_value: 0.0353821926
#           }
#           values {
#             number_value: 0.0667846277
#           }
#           values {
#             number_value: 0.00392828975
#           }
#           values {
#             number_value: -0.0297232084
#           }
#           values {
#             number_value: 0.000596594706
#           }
#           values {
#             number_value: -0.0672189072
#           }
#           values {
#             number_value: 0.0202280208
#           }
#           values {
#             number_value: 0.0129409833
#           }
#           values {
#             number_value: 0.0211658906
#           }
#           values {
#             number_value: 0.00444782246
#           }
#           values {
#             number_value: -0.00486385589
#           }
#           values {
#             number_value: 0.0310796313
#           }
#           values {
#             number_value: 0.0300501
#           }
#           values {
#             number_value: 0.00116578082
#           }
#           values {
#             number_value: -0.0502911173
#           }
#           values {
#             number_value: 0.0040990524
#           }
#           values {
#             number_value: -0.0241749547
#           }
#           values {
#             number_value: 0.0170720872
#           }
#           values {
#             number_value: 0.0417043976
#           }
#           values {
#             number_value: -0.0125873396
#           }
#           values {
#             number_value: -0.038714461
#           }
#           values {
#             number_value: 0.00794393197
#           }
#           values {
#             number_value: 0.00108350045
#           }
#           values {
#             number_value: -0.0220772866
#           }
#           values {
#             number_value: -0.0237242989
#           }
#           values {
#             number_value: 0.0163675565
#           }
#           values {
#             number_value: -0.023996355
#           }
#           values {
#             number_value: 0.000889643969
#           }
#           values {
#             number_value: 0.0579357781
#           }
#           values {
#             number_value: -0.00738307
#           }
#           values {
#             number_value: 0.0248928815
#           }
#           values {
#             number_value: -0.00818912126
#           }
#           values {
#             number_value: -0.0177577864
#           }
#           values {
#             number_value: -0.0549912639
#           }
#           values {
#             number_value: 0.00380237401
#           }
#           values {
#             number_value: 0.00150535232
#           }
#           values {
#             number_value: -0.00214157323
#           }
#           values {
#             number_value: 0.00786154903
#           }
#           values {
#             number_value: -0.00231924444
#           }
#           values {
#             number_value: 0.0156085482
#           }
#           values {
#             number_value: 0.0217372831
#           }
#           values {
#             number_value: 0.0094956914
#           }
#           values {
#             number_value: 0.0104018506
#           }
#           values {
#             number_value: -0.0189726185
#           }
#           values {
#             number_value: 0.0309151709
#           }
#           values {
#             number_value: 0.0131368665
#           }
#           values {
#             number_value: 0.000819865556
#           }
#           values {
#             number_value: -0.0422569811
#           }
#           values {
#             number_value: 0.0052261455
#           }
#           values {
#             number_value: 0.0255397521
#           }
#           values {
#             number_value: 0.000284619658
#           }
#           values {
#             number_value: 0.00605689315
#           }
#           values {
#             number_value: -0.0341297127
#           }
#           values {
#             number_value: 0.012881686
#           }
#           values {
#             number_value: -0.013272943
#           }
#           values {
#             number_value: 0.00899352133
#           }
#           values {
#             number_value: 0.0283368621
#           }
#           values {
#             number_value: -0.0255904905
#           }
#           values {
#             number_value: -0.0160379969
#           }
#           values {
#             number_value: -0.0253194496
#           }
#           values {
#             number_value: -0.00205910509
#           }
#           values {
#             number_value: -0.00222520158
#           }
#           values {
#             number_value: 0.00445012283
#           }
#           values {
#             number_value: -0.0219850279
#           }
#           values {
#             number_value: -0.0417409688
#           }
#           values {
#             number_value: 0.0384112708
#           }
#           values {
#             number_value: -0.0217506047
#           }
#           values {
#             number_value: -0.0378291905
#           }
#           values {
#             number_value: -0.0115899313
#           }
#           values {
#             number_value: -0.016410917
#           }
#           values {
#             number_value: -0.0247935
#           }
#           values {
#             number_value: -0.0303073935
#           }
#           values {
#             number_value: 0.0356642045
#           }
#           values {
#             number_value: 0.00915069878
#           }
#           values {
#             number_value: -0.0128256865
#           }
#           values {
#             number_value: 0.0426439121
#           }
#           values {
#             number_value: -0.0531984046
#           }
#           values {
#             number_value: 0.019345805
#           }
#           values {
#             number_value: -0.00032419659
#           }
#           values {
#             number_value: 0.0241924822
#           }
#           values {
#             number_value: 0.00933136139
#           }
#           values {
#             number_value: -0.01591786
#           }
#           values {
#             number_value: -0.0133938035
#           }
#           values {
#             number_value: -0.0302669629
#           }
#           values {
#             number_value: -0.00491504092
#           }
#           values {
#             number_value: 0.0266506765
#           }
#           values {
#             number_value: -0.00456271973
#           }
#           values {
#             number_value: 0.000684860162
#           }
#           values {
#             number_value: 0.0172968078
#           }
#           values {
#             number_value: 0.00535398256
#           }
#           values {
#             number_value: 0.00883600675
#           }
#           values {
#             number_value: -0.00361371925
#           }
#           values {
#             number_value: -0.0345249027
#           }
#           values {
#             number_value: -0.0321936756
#           }
#           values {
#             number_value: -0.0109265875
#           }
#           values {
#             number_value: 0.0108120199
#           }
#           values {
#             number_value: -0.0232934337
#           }
#           values {
#             number_value: -0.00455022184
#           }
#           values {
#             number_value: 0.0118651651
#           }
#           values {
#             number_value: 0.00826678239
#           }
#           values {
#             number_value: -0.0333974659
#           }
#           values {
#             number_value: 0.0107603399
#           }
#           values {
#             number_value: 0.00537484558
#           }
#           values {
#             number_value: 0.0162182171
#           }
#           values {
#             number_value: -0.00534466607
#           }
#           values {
#             number_value: -0.0253271069
#           }
#           values {
#             number_value: 0.00518629421
#           }
#           values {
#             number_value: 0.00563201541
#           }
#           values {
#             number_value: 0.0128806615
#           }
#           values {
#             number_value: -0.0152791403
#           }
#           values {
#             number_value: 0.0311624818
#           }
#           values {
#             number_value: -0.00196387689
#           }
#           values {
#             number_value: 0.00881946366
#           }
#           values {
#             number_value: 0.0610771738
#           }
#           values {
#             number_value: 0.0122232204
#           }
#           values {
#             number_value: -0.00846197642
#           }
#           values {
#             number_value: -0.00421379833
#           }
#           values {
#             number_value: 0.00700675463
#           }
#           values {
#             number_value: -0.00852408
#           }
#           values {
#             number_value: 0.0087260874
#           }
#           values {
#             number_value: 0.0127288187
#           }
#           values {
#             number_value: -0.0210556481
#           }
#           values {
#             number_value: -0.00947697181
#           }
#           values {
#             number_value: 0.0381575599
#           }
#           values {
#             number_value: -0.0123405615
#           }
#           values {
#             number_value: -0.0171060469
#           }
#           values {
#             number_value: 0.00732520455
#           }
#           values {
#             number_value: 0.0443923511
#           }
#           values {
#             number_value: -0.012058082
#           }
#           values {
#             number_value: -0.0162367113
#           }
#           values {
#             number_value: -0.048086118
#           }
#           values {
#             number_value: 0.000588099298
#           }
#           values {
#             number_value: 0.0115934815
#           }
#           values {
#             number_value: -0.00311317667
#           }
#           values {
#             number_value: -0.017642878
#           }
#           values {
#             number_value: 0.00972890295
#           }
#           values {
#             number_value: -0.0340872705
#           }
#           values {
#             number_value: 0.0318860933
#           }
#           values {
#             number_value: -0.0201374106
#           }
#           values {
#             number_value: 0.0473696142
#           }
#           values {
#             number_value: 0.0118889343
#           }
#           values {
#             number_value: -0.0168103278
#           }
#           values {
#             number_value: -0.0322745442
#           }
#           values {
#             number_value: 0.00909967441
#           }
#           values {
#             number_value: 0.0282382295
#           }
#           values {
#             number_value: -0.0212033987
#           }
#           values {
#             number_value: 0.0115688704
#           }
#           values {
#             number_value: -0.0322875492
#           }
#           values {
#             number_value: 0.0173203424
#           }
#           values {
#             number_value: -0.00358803477
#           }
#           values {
#             number_value: 0.0138825057
#           }
#           values {
#             number_value: -0.0162338819
#           }
#           values {
#             number_value: -0.0152344573
#           }
#           values {
#             number_value: 0.0110543948
#           }
#           values {
#             number_value: -0.00225748331
#           }
#           values {
#             number_value: -0.0210925285
#           }
#           values {
#             number_value: 0.0045279623
#           }
#           values {
#             number_value: -0.00303348829
#           }
#           values {
#             number_value: 0.020273447
#           }
#           values {
#             number_value: -0.00929529499
#           }
#           values {
#             number_value: -0.0171969
#           }
#           values {
#             number_value: -0.0367237888
#           }
#           values {
#             number_value: -0.0101470044
#           }
#           values {
#             number_value: 0.0120232301
#           }
#           values {
#             number_value: -0.026592955
#           }
#           values {
#             number_value: -0.015845811
#           }
#           values {
#             number_value: -0.0412941873
#           }
#           values {
#             number_value: -0.0264274646
#           }
#           values {
#             number_value: -0.00834013801
#           }
#           values {
#             number_value: -0.0408997238
#           }
#           values {
#             number_value: -0.00736826286
#           }
#           values {
#             number_value: -0.0214883797
#           }
#           values {
#             number_value: 0.0409364589
#           }
#           values {
#             number_value: -0.0176723897
#           }
#           values {
#             number_value: -0.0499743782
#           }
#           values {
#             number_value: 0.00473295804
#           }
#           values {
#             number_value: 0.00741005922
#           }
#           values {
#             number_value: 0.00235634716
#           }
#           values {
#             number_value: 0.0254155565
#           }
#           values {
#             number_value: 0.01498436
#           }
#           values {
#             number_value: -0.00554795284
#           }
#           values {
#             number_value: -0.0158026535
#           }
#           values {
#             number_value: -0.0492141917
#           }
#           values {
#             number_value: -0.0145005742
#           }
#           values {
#             number_value: -0.0258047637
#           }
#           values {
#             number_value: -0.0338218622
#           }
#           values {
#             number_value: 0.0284354575
#           }
#           values {
#             number_value: -0.0367100313
#           }
#           values {
#             number_value: 0.0030919381
#           }
#           values {
#             number_value: -0.0242381897
#           }
#           values {
#             number_value: 0.0258777644
#           }
#           values {
#             number_value: -0.0107640009
#           }
#           values {
#             number_value: -0.0416978449
#           }
#           values {
#             number_value: -0.00306800148
#           }
#           values {
#             number_value: 0.0423430316
#           }
#           values {
#             number_value: 0.0143221235
#           }
#           values {
#             number_value: 0.0192648694
#           }
#           values {
#             number_value: -0.0102699623
#           }
#           values {
#             number_value: -1.05571453e-05
#           }
#           values {
#             number_value: -0.0248098169
#           }
#           values {
#             number_value: -0.0076645962
#           }
#           values {
#             number_value: 0.0363356955
#           }
#           values {
#             number_value: -0.0138589041
#           }
#           values {
#             number_value: 0.0355939344
#           }
#           values {
#             number_value: -0.0151554728
#           }
#           values {
#             number_value: -0.029587768
#           }
#           values {
#             number_value: -0.0109273233
#           }
#           values {
#             number_value: 0.0154775139
#           }
#           values {
#             number_value: 0.0236593485
#           }
#           values {
#             number_value: 0.0515776463
#           }
#           values {
#             number_value: 0.0254721828
#           }
#           values {
#             number_value: -0.0345260389
#           }
#           values {
#             number_value: 0.0176568776
#           }
#           values {
#             number_value: -0.00421560416
#           }
#           values {
#             number_value: -0.012264342
#           }
#           values {
#             number_value: 0.0172102265
#           }
#           values {
#             number_value: -0.0101398956
#           }
#           values {
#             number_value: -0.0163402706
#           }
#           values {
#             number_value: -0.0136894248
#           }
#           values {
#             number_value: -0.0249035396
#           }
#           values {
#             number_value: -0.0200836081
#           }
#           values {
#             number_value: 0.0127844429
#           }
#           values {
#             number_value: 0.00232120091
#           }
#           values {
#             number_value: 0.060169369
#           }
#           values {
#             number_value: -0.0346778
#           }
#           values {
#             number_value: 0.00434221467
#           }
#           values {
#             number_value: -0.0154635487
#           }
#           values {
#             number_value: -0.0161192659
#           }
#           values {
#             number_value: -0.00235516671
#           }
#           values {
#             number_value: 0.00420789421
#           }
#           values {
#             number_value: 0.00256934157
#           }
#           values {
#             number_value: -0.0164963752
#           }
#           values {
#             number_value: -0.0298812073
#           }
#           values {
#             number_value: -0.0182082411
#           }
#           values {
#             number_value: 0.0352284163
#           }
#           values {
#             number_value: -0.0145195564
#           }
#           values {
#             number_value: 0.0139059564
#           }
#           values {
#             number_value: 0.0336555019
#           }
#           values {
#             number_value: 0.0182117317
#           }
#           values {
#             number_value: -0.00850193389
#           }
#           values {
#             number_value: -0.0211756583
#           }
#           values {
#             number_value: 0.0193865635
#           }
#           values {
#             number_value: 0.0389054455
#           }
#           values {
#             number_value: 0.0239063129
#           }
#           values {
#             number_value: -0.0129411388
#           }
#           values {
#             number_value: -0.00754191866
#           }
#           values {
#             number_value: 0.014568246
#           }
#           values {
#             number_value: 0.0361678526
#           }
#           values {
#             number_value: -0.00913815759
#           }
#           values {
#             number_value: 0.0220094547
#           }
#           values {
#             number_value: -0.0412369147
#           }
#           values {
#             number_value: -0.00437308336
#           }
#           values {
#             number_value: 0.0403102972
#           }
#           values {
#             number_value: 0.0244382452
#           }
#           values {
#             number_value: -0.00675266236
#           }
#           values {
#             number_value: -0.0396543518
#           }
#           values {
#             number_value: 0.0247357935
#           }
#           values {
#             number_value: 0.0128912916
#           }
#           values {
#             number_value: -0.0233153775
#           }
#           values {
#             number_value: -0.0409953669
#           }
#           values {
#             number_value: -0.0152226891
#           }
#           values {
#             number_value: 0.00554634072
#           }
#           values {
#             number_value: -0.00869789161
#           }
#           values {
#             number_value: 0.00446184631
#           }
#           values {
#             number_value: -0.013927958
#           }
#           values {
#             number_value: 0.00551535096
#           }
#           values {
#             number_value: 0.0188327227
#           }
#           values {
#             number_value: -0.0174510181
#           }
#           values {
#             number_value: -0.0138011482
#           }
#           values {
#             number_value: 0.00656768773
#           }
#           values {
#             number_value: -0.0145947076
#           }
#           values {
#             number_value: -0.0247601625
#           }
#           values {
#             number_value: 0.0331601612
#           }
#           values {
#             number_value: 0.0107643213
#           }
#           values {
#             number_value: 0.046376
#           }
#           values {
#             number_value: -0.0390241146
#           }
#           values {
#             number_value: -0.0240546446
#           }
#           values {
#             number_value: -0.0279463846
#           }
#           values {
#             number_value: 0.00317422953
#           }
#           values {
#             number_value: -0.00656261481
#           }
#           values {
#             number_value: 0.0110651068
#           }
#           values {
#             number_value: -0.0230471827
#           }
#           values {
#             number_value: -0.0399107
#           }
#           values {
#             number_value: -0.00127679657
#           }
#           values {
#             number_value: -0.00356133934
#           }
#           values {
#             number_value: 0.0434180424
#           }
#           values {
#             number_value: -0.0128631936
#           }
#           values {
#             number_value: -0.00776531547
#           }
#           values {
#             number_value: 0.0182178263
#           }
#           values {
#             number_value: -0.0301856231
#           }
#           values {
#             number_value: -0.0151436441
#           }
#           values {
#             number_value: -0.0356395319
#           }
#           values {
#             number_value: -0.00629735272
#           }
#           values {
#             number_value: 0.00505462848
#           }
#           values {
#             number_value: -0.0182744097
#           }
#           values {
#             number_value: 0.00837399717
#           }
#           values {
#             number_value: 0.0407358631
#           }
#           values {
#             number_value: -0.0239841416
#           }
#           values {
#             number_value: -0.00840784144
#           }
#           values {
#             number_value: 0.0526370518
#           }
#           values {
#             number_value: -0.00695174141
#           }
#           values {
#             number_value: 0.00885173399
#           }
#           values {
#             number_value: -0.0228428394
#           }
#           values {
#             number_value: -0.0138603784
#           }
#           values {
#             number_value: 0.0116465
#           }
#           values {
#             number_value: -0.00830873474
#           }
#           values {
#             number_value: -0.00806277
#           }
#           values {
#             number_value: 0.0101645263
#           }
#           values {
#             number_value: -0.00248916238
#           }
#           values {
#             number_value: -0.00436411239
#           }
#           values {
#             number_value: 0.0155193582
#           }
#           values {
#             number_value: 0.043876458
#           }
#           values {
#             number_value: 0.0454746857
#           }
#           values {
#             number_value: -0.00683928095
#           }
#           values {
#             number_value: -0.0244892333
#           }
#           values {
#             number_value: 0.0182999503
#           }
#           values {
#             number_value: -0.0371354036
#           }
#           values {
#             number_value: 0.0391402505
#           }
#           values {
#             number_value: -0.00964118075
#           }
#           values {
#             number_value: 0.0132386442
#           }
#           values {
#             number_value: -0.00672504865
#           }
#           values {
#             number_value: -0.0067174728
#           }
#           values {
#             number_value: 0.00422340399
#           }
#           values {
#             number_value: -0.00805101357
#           }
#           values {
#             number_value: -0.0307248905
#           }
#           values {
#             number_value: -0.00810711458
#           }
#           values {
#             number_value: 0.0143509265
#           }
#           values {
#             number_value: 0.0545470417
#           }
#           values {
#             number_value: 0.00972214341
#           }
#           values {
#             number_value: -0.0114781307
#           }
#           values {
#             number_value: -0.0317166299
#           }
#           values {
#             number_value: 0.0219878145
#           }
#           values {
#             number_value: -0.0260557253
#           }
#           values {
#             number_value: 0.0121787013
#           }
#           values {
#             number_value: -0.0631516576
#           }
#           values {
#             number_value: -0.0157661475
#           }
#           values {
#             number_value: -0.026639184
#           }
#           values {
#             number_value: 0.0284311
#           }
#           values {
#             number_value: -0.0123592764
#           }
#           values {
#             number_value: -0.0112748314
#           }
#           values {
#             number_value: -0.000938645913
#           }
#           values {
#             number_value: -0.0194483548
#           }
#           values {
#             number_value: 0.00724894367
#           }
#           values {
#             number_value: -0.0191984698
#           }
#           values {
#             number_value: 0.00877004862
#           }
#           values {
#             number_value: 0.00931487232
#           }
#           values {
#             number_value: 0.00567013631
#           }
#           values {
#             number_value: 0.0339020975
#           }
#           values {
#             number_value: -0.0198287368
#           }
#           values {
#             number_value: -0.00131643342
#           }
#           values {
#             number_value: -0.00543163251
#           }
#           values {
#             number_value: 0.0141763976
#           }
#           values {
#             number_value: 0.0288597047
#           }
#           values {
#             number_value: -0.00405909587
#           }
#           values {
#             number_value: 0.0398561284
#           }
#           values {
#             number_value: -0.00748756435
#           }
#           values {
#             number_value: 0.070159927
#           }
#           values {
#             number_value: -0.0197898094
#           }
#           values {
#             number_value: 0.00775410235
#           }
#           values {
#             number_value: -0.12345285
#           }
#           values {
#             number_value: -0.0224019215
#           }
#           values {
#             number_value: -0.00557387527
#           }
#           values {
#             number_value: 0.00572973071
#           }
#           values {
#             number_value: -0.00825713109
#           }
#           values {
#             number_value: -0.0174935237
#           }
#           values {
#             number_value: 0.034109287
#           }
#           values {
#             number_value: -0.0033031872
#           }
#           values {
#             number_value: 0.0589072183
#           }
#           values {
#             number_value: 0.0246177446
#           }
#           values {
#             number_value: 0.0210620202
#           }
#           values {
#             number_value: 0.0267741289
#           }
#           values {
#             number_value: -0.235378623
#           }
#           values {
#             number_value: 0.066302754
#           }
#           values {
#             number_value: 0.00827238336
#           }
#           values {
#             number_value: 0.0203243289
#           }
# ...
#             number_value: -0.0173126869
#           }
#           values {
#             number_value: -0.00333492341
#           }
#           values {
#             number_value: 0.0284877345
#           }
#           values {
#             number_value: -0.00156622869
#           }
#           values {
#             number_value: 0.00479952758
#           }
#           values {
#             number_value: 0.025557613
#           }
#           values {
#             number_value: -0.00767272385
#           }
#           values {
#             number_value: -0.00678631896
#           }
#           values {
#             number_value: 0.00633334555
#           }
#           values {
#             number_value: -0.013315904
#           }
#           values {
#             number_value: 0.0196498428
#           }
#           values {
#             number_value: 0.00750464341
#           }
#           values {
#             number_value: -0.0344275907
#           }
#           values {
#             number_value: 0.00777099794
#           }
#           values {
#             number_value: 0.00660667196
#           }
#           values {
#             number_value: -0.0165293384
#           }
#           values {
#             number_value: -0.0306836944
#           }
#           values {
#             number_value: 0.00105256517
#           }
#           values {
#             number_value: -0.046379637
#           }
#           values {
#             number_value: -0.0121183861
#           }
#           values {
#             number_value: 0.00448327791
#           }
#           values {
#             number_value: -0.00717267161
#           }
#           values {
#             number_value: -0.00186080427
#           }
#           values {
#             number_value: -0.0251563881
#           }
#           values {
#             number_value: -0.000508432684
#           }
#           values {
#             number_value: -0.00899518747
#           }
#           values {
#             number_value: -0.00476380764
#           }
#           values {
#             number_value: 0.0148633616
#           }
#           values {
#             number_value: -0.0516715944
#           }
#           values {
#             number_value: -0.0065722079
#           }
#           values {
#             number_value: -0.0270429943
#           }
#           values {
#             number_value: -0.0159756318
#           }
#           values {
#             number_value: 0.0148417745
#           }
#           values {
#             number_value: 0.0122024715
#           }
#           values {
#             number_value: 0.00221975055
#           }
#           values {
#             number_value: 0.00525396084
#           }
#           values {
#             number_value: 0.024793027
#           }
#           values {
#             number_value: -0.0161640458
#           }
#           values {
#             number_value: -0.0121009843
#           }
#           values {
#             number_value: 0.0175328851
#           }
#           values {
#             number_value: 0.00454984652
#           }
#           values {
#             number_value: -0.0200596098
#           }
#           values {
#             number_value: -0.0111056026
#           }
#           values {
#             number_value: 0.00455968222
#           }
#           values {
#             number_value: 0.00310079521
#           }
#           values {
#             number_value: -0.0159442127
#           }
#           values {
#             number_value: -0.033943627
#           }
#           values {
#             number_value: -0.00488464488
#           }
#           values {
#             number_value: 0.0506170765
#           }
#           values {
#             number_value: -0.0167657435
#           }
#           values {
#             number_value: -0.0277908202
#           }
#           values {
#             number_value: -0.0557409488
#           }
#           values {
#             number_value: 0.0177237764
#           }
#           values {
#             number_value: -0.00582813146
#           }
#           values {
#             number_value: -0.0148983216
#           }
#           values {
#             number_value: -0.035629224
#           }
#           values {
#             number_value: 0.00795484334
#           }
#           values {
#             number_value: 0.055958841
#           }
#           values {
#             number_value: -0.0611435026
#           }
#           values {
#             number_value: 0.0192448441
#           }
#           values {
#             number_value: -0.0426664166
#           }
#           values {
#             number_value: 0.00196414255
#           }
#           values {
#             number_value: -0.0142259672
#           }
#           values {
#             number_value: 0.00348691316
#           }
#           values {
#             number_value: -0.0230666474
#           }
#           values {
#             number_value: -0.0125858895
#           }
#           values {
#             number_value: -0.0198509358
#           }
#           values {
#             number_value: -0.00885927584
#           }
#           values {
#             number_value: 0.00318312971
#           }
#           values {
#             number_value: 0.0244246423
#           }
#           values {
#             number_value: -0.0219473988
#           }
#           values {
#             number_value: -0.0229131505
#           }
#           values {
#             number_value: -0.0119662238
#           }
#           values {
#             number_value: -0.0140686724
#           }
#           values {
#             number_value: 0.0334347822
#           }
#           values {
#             number_value: -0.0148878768
#           }
#           values {
#             number_value: 0.0016507121
#           }
#           values {
#             number_value: -0.00301693287
#           }
#           values {
#             number_value: -0.0187796224
#           }
#           values {
#             number_value: -0.00881315209
#           }
#           values {
#             number_value: 0.0229424033
#           }
#           values {
#             number_value: 0.0105057694
#           }
#           values {
#             number_value: -0.0245272517
#           }
#           values {
#             number_value: 0.0212990232
#           }
#           values {
#             number_value: -0.0150207039
#           }
#           values {
#             number_value: -0.0293313377
#           }
#           values {
#             number_value: -0.0476163067
#           }
#           values {
#             number_value: -0.0160354599
#           }
#           values {
#             number_value: -0.0143094156
#           }
#           values {
#             number_value: 0.0303469114
#           }
#           values {
#             number_value: 0.0449421
#           }
#           values {
#             number_value: 0.0179364067
#           }
#           values {
#             number_value: 0.00269464822
#           }
#           values {
#             number_value: -0.00031354191
#           }
#           values {
#             number_value: 0.00875216909
#           }
#           values {
#             number_value: -0.0162187647
#           }
#           values {
#             number_value: 0.0232562218
#           }
#           values {
#             number_value: 0.0213727076
#           }
#           values {
#             number_value: -0.00686839409
#           }
#           values {
#             number_value: 0.0377417728
#           }
#           values {
#             number_value: 0.0426960625
#           }
#           values {
#             number_value: 0.00392151577
#           }
#           values {
#             number_value: 0.00826242194
#           }
#           values {
#             number_value: -0.0218912214
#           }
#           values {
#             number_value: 0.0619236343
#           }
#           values {
#             number_value: -0.0337650925
#           }
#           values {
#             number_value: -0.0201240182
#           }
#           values {
#             number_value: -0.00201814668
#           }
#           values {
#             number_value: 0.00117351708
#           }
#           values {
#             number_value: 0.00948006473
#           }
#           values {
#             number_value: 0.00132741081
#           }
#           values {
#             number_value: 0.0192386843
#           }
#           values {
#             number_value: 0.0141741037
#           }
#           values {
#             number_value: -0.00711739296
#           }
#           values {
#             number_value: -0.0359606631
#           }
#           values {
#             number_value: 0.00852477457
#           }
#           values {
#             number_value: -0.00679532252
#           }
#           values {
#             number_value: 0.000730422151
#           }
#           values {
#             number_value: 0.000645820459
#           }
#           values {
#             number_value: -0.00580409495
#           }
#           values {
#             number_value: -0.0458843224
#           }
#           values {
#             number_value: 0.0366280265
#           }
#           values {
#             number_value: -0.0187807083
#           }
#           values {
#             number_value: -0.0180006959
#           }
#           values {
#             number_value: 0.0255250949
#           }
#           values {
#             number_value: -0.0146149192
#           }
#           values {
#             number_value: -0.0246806666
#           }
#           values {
#             number_value: -0.026289979
#           }
#           values {
#             number_value: 0.0283734575
#           }
#           values {
#             number_value: 0.0269036628
#           }
#           values {
#             number_value: -0.0331382789
#           }
#           values {
#             number_value: 0.0276791491
#           }
#           values {
#             number_value: 0.00722272927
#           }
#           values {
#             number_value: 0.0281602517
#           }
#           values {
#             number_value: 0.00122966478
#           }
#           values {
#             number_value: 0.0124320099
#           }
#           values {
#             number_value: -0.00370825687
#           }
#           values {
#             number_value: 0.0190312378
#           }
#           values {
#             number_value: -0.0985312313
#           }
#           values {
#             number_value: -0.0130078271
#           }
#           values {
#             number_value: -0.0161239654
#           }
#           values {
#             number_value: 0.00985175092
#           }
#           values {
#             number_value: -0.00416275114
#           }
#           values {
#             number_value: -0.0390838981
#           }
#           values {
#             number_value: 0.00136698573
#           }
#           values {
#             number_value: 0.0017087959
#           }
#           values {
#             number_value: -0.0627589673
#           }
#           values {
#             number_value: -0.0497060157
#           }
#           values {
#             number_value: 0.0153702348
#           }
#           values {
#             number_value: 0.0108023696
#           }
#           values {
#             number_value: -0.00380573841
#           }
#           values {
#             number_value: -0.0197328888
#           }
#           values {
#             number_value: 0.0238909386
#           }
#           values {
#             number_value: 0.00359836104
#           }
#           values {
#             number_value: -0.0251022726
#           }
#           values {
#             number_value: -0.00233923434
#           }
#           values {
#             number_value: -0.00510132639
#           }
#           values {
#             number_value: -0.0231698304
#           }
#           values {
#             number_value: 0.00803965423
#           }
#           values {
#             number_value: 0.0171765033
#           }
#           values {
#             number_value: -0.0369826816
#           }
#           values {
#             number_value: -0.0187807735
#           }
#           values {
#             number_value: -0.0018672531
#           }
#           values {
#             number_value: 0.0142110856
#           }
#           values {
#             number_value: -0.0515948571
#           }
#           values {
#             number_value: 0.0307680648
#           }
#           values {
#             number_value: -0.00527135143
#           }
#           values {
#             number_value: -0.000266024028
#           }
#           values {
#             number_value: 0.0237010494
#           }
#           values {
#             number_value: 0.022852242
#           }
#           values {
#             number_value: 0.0160284936
#           }
#           values {
#             number_value: 0.023874145
#           }
#           values {
#             number_value: 0.00300565036
#           }
#           values {
#             number_value: -0.0202827379
#           }
#           values {
#             number_value: -0.027979752
#           }
#           values {
#             number_value: 0.0280493181
#           }
#           values {
#             number_value: 0.0473452024
#           }
#           values {
#             number_value: -0.000618019316
#           }
#           values {
#             number_value: 0.0338843726
#           }
#           values {
#             number_value: 0.0479000509
#           }
#           values {
#             number_value: -0.000575123762
#           }
#           values {
#             number_value: -0.0552132092
#           }
#           values {
#             number_value: -0.00757762231
#           }
#           values {
#             number_value: -0.0152946478
#           }
#           values {
#             number_value: 0.0532572344
#           }
#           values {
#             number_value: 0.0116274981
#           }
#           values {
#             number_value: 0.000412571855
#           }
#           values {
#             number_value: -0.0425886512
#           }
#           values {
#             number_value: 0.0273351055
#           }
#           values {
#             number_value: -0.0175442882
#           }
#           values {
#             number_value: 0.02694932
#           }
#           values {
#             number_value: -0.0371636301
#           }
#           values {
#             number_value: 0.00623925356
#           }
#           values {
#             number_value: -0.00968775898
#           }
#           values {
#             number_value: 0.00865639094
#           }
#           values {
#             number_value: 0.00817076769
#           }
#           values {
#             number_value: 0.00534231495
#           }
#           values {
#             number_value: 0.00816785265
#           }
#           values {
#             number_value: -0.021633761
#           }
#           values {
#             number_value: 0.0338053033
#           }
#           values {
#             number_value: 0.0101131173
#           }
#           values {
#             number_value: -0.0353311822
#           }
#           values {
#             number_value: -0.0237005372
#           }
#           values {
#             number_value: 0.00769319851
#           }
#           values {
#             number_value: 0.00103325769
#           }
#           values {
#             number_value: -0.0227466412
#           }
#           values {
#             number_value: -0.032069277
#           }
#           values {
#             number_value: 0.0428079776
#           }
#           values {
#             number_value: -0.0114392983
#           }
#           values {
#             number_value: -0.0293532461
#           }
#           values {
#             number_value: -0.0457063429
#           }
#           values {
#             number_value: -0.0273780711
#           }
#           values {
#             number_value: -0.0124086384
#           }
#           values {
#             number_value: 0.0322644673
#           }
#           values {
#             number_value: 0.0311357453
#           }
#           values {
#             number_value: 0.0114750564
#           }
#           values {
#             number_value: -0.0126919579
#           }
#           values {
#             number_value: -0.000255608727
#           }
#           values {
#             number_value: -0.0179370735
#           }
#           values {
#             number_value: -0.0282705184
#           }
#           values {
#             number_value: 0.0417771526
#           }
#         }
#       }
#     }
#   }
# }
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# [' The image shows Joe Biden, the 46th president of the United States, standing next to Hunter Biden, his son, and Rudy Giuliani, a former mayor of New York City and personal attorney for Donald Trump. The three men are standing in front of the White House.']

# %% [markdown]
# ### Create bucket and push embeddings into the bucket

# %%
embeddings
# Out:
# [None]

# %%
#set bucket info to create a bucket
BUCKET_URI = f"gs://artifacts-{PROJECT_ID}-unique"  # @param {type:"string"}
! gsutil mb -l {REGION} -p {PROJECT_ID} {BUCKET_URI}

# %%
UNIQUE_FOLDER_NAME = "embeddings_results_NinePOC"

# %%
#embeddings
EMBEDDINGS_INITIAL_URI = f"{BUCKET_URI}/{UNIQUE_FOLDER_NAME}/"
! gsutil cp {embeddings_file.name} {EMBEDDINGS_INITIAL_URI}

#summaries
EMBEDDINGS_INITIAL_URI = f"{BUCKET_URI}/{UNIQUE_FOLDER_NAME}/"
! gsutil cp {summaries_file.name} {EMBEDDINGS_INITIAL_URI}

# %%
#save the temp files in persistent disk
import tempfile, shutil
 
file_name = embeddings_file.name
embeddings_file.close()
shutil.copy(file_name, 'embeddings_file.json')

file_name = summaries_file.name
summaries_file.close()
shutil.copy(file_name, 'summaries_file.json')
# Out:
# 'summaries_file.json'
