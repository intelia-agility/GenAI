# %%
import time
import random
from google.cloud import functions_v2
from google.cloud import aiplatform
from EmbeddingPredictionClient import EmbeddingPredictionClient  
from google.cloud import bigquery
import json

# Initialize the EmbeddingPredictionClient outside the function for reuse
embedding_client = EmbeddingPredictionClient(project='nine-quality-test' , location="us-central1",api_regional_endpoint="us-central1-aiplatform.googleapis.com")

def exponential_backoff_retries(client, text=None, image_file=None, max_retries=5, embedding_type=None):
    """
    This function applies exponential backoff with retries to the API calls.
    """
    attempt = 0
    while attempt < max_retries:
        try:
            # Try to get the embedding from the client
            if embedding_type=="multimodal_embedding":
                    return client.get_multimodal_embedding(text, image_file)
            elif embedding_type=="text_embedding":
                    return client.get_text_embedding(text)
        except Exception as e:
            attempt += 1
            backoff_delay = min(2 ** attempt + random.uniform(0, 1), 32)  # Exponential backoff with jitter
            print(f"Attempt {attempt} failed with error {e}. Retrying in {backoff_delay:.2f} seconds...")
            time.sleep(backoff_delay)  # Wait before retrying

    raise Exception("Max retries reached. Could not complete the request.")

def search_content_function(request):
    """
    Cloud Function entry point. This function handles the incoming request, 
    performs exponential backoff retries, and returns the embedding response.
    """
    # Parse the incoming request to extract text or image file
    request_json = request.get_json(silent=True)
    text = request_json.get('text')
    image_file = request_json.get('image_file')  # Assume it's the path or base64 string of the image

    if not text and not image_file:
        return 'Error: At least one of "text" or "image_file" must be provided.', 400

    try:
        # Retry logic with exponential backoff to calculate query embeddings
        result = exponential_backoff_retries(embedding_client, text, image_file)
        
        # Respond with the successful embedding response
        return {
            "text_embedding": result.text_embedding,
            "image_embedding": result.image_embedding
        }, 200

    except Exception as e:
        # Handle failure after max retries
        return f"Error: {str(e)}", 500

# %%
response=exponential_backoff_retries(embedding_client, 'bedroom with gray carpet', embedding_type='text_embedding').text_embedding

# %%
response=exponential_backoff_retries(embedding_client, 'this is a test', embedding_type='multimodal_embedding').text_embedding

# %%
def query_nearest_neighbors(query_embedding, table, dataset,source_embedding_column,project_id,top_k=50):
    """Query nearest neighbors using cosine similarity in BigQuery."""
    
    # SQL for finding the nearest neighbors using cosine similarity
    sql = f"""
    WITH query_embedding AS (
        SELECT {json.dumps(query_embedding)} AS embedding
    )
    SELECT
      base.uri AS gcs_uri,  -- URI of the matching image or record
      distance  -- The computed distance (similarity score) between the embeddings
    FROM
      VECTOR_SEARCH(     
        TABLE `{dataset}.{table}`, --source embedding table
        '{source_embedding_column}',  -- Column with the embedding vectors in the base table

        -- Use the query embedding computed in the previous step
        query_embedding.query_embedding AS query_embedding,  -- The query embedding from the CTE (query_embedding)

        -- Return top-k closest matches (adjust k as necessary)
        top_k =>{ top_k } -- Top 3 most similar matches based on distance
      )
    """
    
    bq_client = bigquery.Client(project_id)
  
    # Run the query
    query_job = bq_client.query(sql)

    # Fetch results
    results = query_job.result()

    return [(row.text, row.cosine_similarity) for row in results]

# %%
PROJECT = !gcloud config get-value project
PROJECT_ID = PROJECT[0]
REGION = "us-central1"

# %%
query_embedding=response
top_k=50
project_id=PROJECT_ID
dataset='langchain_dataset'
table='vlt_media_content_text_test_for_search'
247543, -0.018494978547096252, 0.031261734664440155, 0.01541661936789751, 0.04358125850558281, 0.008710736408829689, -0.04056102782487869, -0.04981791600584984, 0.021344413980841637, 0.005989321041852236, 0.01253937091678381, 0.005740383639931679, -0.03353390470147133, -0.04006234183907509, 0.060815583914518356, -0.010927553288638592, -0.01255643367767334, 0.011777255684137344, -0.04420406371355057, 0.001149568473920226, 0.012039757333695889, -0.02623102068901062, 0.018599389120936394, 0.0015531982062384486, -0.0359799861907959, 0.05116358771920204, -0.057723965495824814, 0.01642993465065956, 0.02503804676234722, -0.055232927203178406, 0.05421154201030731, 0.009608074091374874, 0.030984319746494293, -0.007159240543842316, -0.03969689831137657, -0.02779187448322773, 0.014756012707948685, 0.02705439366400242, 0.05215569958090782, 0.006576606072485447, 0.006285428069531918, 0.023079797625541687, -0.026722142472863197, 0.050196439027786255, 0.005540597252547741, -0.06383026391267776, 0.002736614318564534, -0.02561139687895775, 0.030883505940437317, 0.056306179612874985, -0.019541295245289803, -0.058811455965042114, 0.02012198604643345, -0.03549885004758835, 0.02893192134797573, -0.04778973385691643, 0.03301401436328888, 0.004533533938229084, 0.031995318830013275, -0.047883402556180954, 0.050482578575611115, -0.005425796378403902, 0.012496956624090672] embed) , top_k => 5, distance_type => 'EUCLIDEAN')

# %%
if 1==1: 
    # SQL for finding the nearest neighbors using cosine similarity
    sql = f"""  
    SELECT * FROM (
         SELECT
          base.content as content,  
          base.combined_id as combined_id,
          distance  -- The computed distance (similarity score) between the embeddings
        FROM
          VECTOR_SEARCH(     
            TABLE `{dataset}.{table}`, --source embedding table
            '{source_embedding_column}',  -- Column with the embedding vectors in the base table

            -- Use the query embedding computed in the previous step
             (SELECT {json.dumps(query_embedding)} query_embedding),  -- The query embedding from the CTE (query_embedding)

            -- Return top-k closest matches (adjust k as necessary)
            top_k =>{ top_k } -- Top 3 most similar matches based on distance
          )
    )
    """
    
    sql = f"""  
     SELECT
      content as content,  
      combined_id as combined_id,
      distance  -- The computed distance (similarity score) between the embeddings
    FROM
      VECTOR_SEARCH(     
        TABLE `{dataset}.{table}`, --source embedding table
        '{source_embedding_column}',  -- Column with the embedding vectors in the base table

        -- Use the query embedding computed in the previous step
         (SELECT {json.dumps(query_embedding)} query_embedding),  -- The query embedding from the CTE (query_embedding)

        -- Return top-k closest matches (adjust k as necessary)
        top_k =>{ top_k } -- Top 3 most similar matches based on distance
      )AS search_results  
    """
    
    bq_client = bigquery.Client(project_id)
  
    # Run the query
    query_job = bq_client.query(sql)

    # Fetch results
    results = query_job.result()
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# Cell In[41], line 45
#      42 query_job = bq_client.query(sql)
#      44 # Fetch results
# ---> 45 results = query_job.result()
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py:1676, in QueryJob.result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1671     remaining_timeout = None
#    1673 if remaining_timeout is None:
#    1674     # Since is_job_done() calls jobs.getQueryResults, which is a
#    1675     # long-running API, don't delay the next request at all.
# -> 1676     while not is_job_done():
#    1677         pass
#    1678 else:
#    1679     # Use a monotonic clock since we don't actually care about
#    1680     # daylight savings or similar, just the elapsed time.
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     149 # pylint: disable=broad-except
#     150 # This function explicitly must deal with broad exceptions.
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#     164     time.sleep(sleep)
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry/retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     206 if not predicate_fn(exc):
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#     214     on_error_fn(exc)
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File /opt/conda/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py:1625, in QueryJob.result.<locals>.is_job_done()
#    1602 if job_failed_exception is not None:
#    1603     # Only try to restart the query job if the job failed for
#    1604     # a retriable reason. For example, don't restart the query
#    (...)
#    1622     # into an exception that can be processed by the
#    1623     # `job_retry` predicate.
#    1624     restart_query_job = True
# -> 1625     raise job_failed_exception
#    1626 else:
#    1627     # Make sure that the _query_results are cached so we
#    1628     # can return a complete RowIterator.
#    (...)
#    1634     # making any extra API calls if the previous loop
#    1635     # iteration fetched the finished job.
#    1636     self._reload_query_results(
#    1637         retry=retry, **reload_query_results_kwargs
#    1638     )
#
# BadRequest: 400 Unrecognized name: content at [3:7]; reason: invalidQuery, location: query, message: Unrecognized name: content at [3:7]
#
# Location: us-central1
# Job ID: ab60b29e-a688-49c6-9d0a-901e757e8dda

# %%
print(sql)
# Out:
#
#      SELECT
#       content as content,
#       combined_id as combined_id,
#       distance  -- The computed distance (similarity score) between the embeddings
#     FROM
#       VECTOR_SEARCH(
#         TABLE `langchain_dataset.vlt_media_content_text_test_for_search`, --source embedding table
#         'ml_generate_embedding_result',  -- Column with the embedding vectors in the base table
#
#         -- Use the query embedding computed in the previous step
#          (SELECT [0.022637085989117622, -0.08744391053915024, -0.05492712929844856, -0.02110053412616253, 0.04241510480642319, -0.0013703806325793266, -0.024699779227375984, -0.039696693420410156, 0.06672497093677521, 0.06633879244327545, 0.0042211259715259075, 0.018288828432559967, -0.05834757164120674, -0.012842142023146152, 0.01653565652668476, -0.036274850368499756, 0.025759322568774223, -0.01664155162870884, -0.008383373729884624, 0.02068745531141758, 0.021755149587988853, -0.015260789543390274, -0.02433032914996147, 0.01211275439709425, -0.008128231391310692, -0.04060431569814682, 0.023532332852482796, -0.04697849601507187, -0.01878499612212181, -0.021921373903751373, -0.061683766543865204, 0.020377835258841515, -0.06735124439001083, 0.020930737257003784, -0.04173501580953598, 0.003094820771366358, 0.026938611641526222, 0.04023854807019234, -0.006536973174661398, 0.02968994528055191, 0.038001030683517456, -0.024572448804974556, -0.04759639501571655, 0.008217457681894302, -0.005991026759147644, -0.01733267493546009, 0.004243812523782253, -0.012839705683290958, 0.010800844989717007, -0.052032023668289185, 0.05365723744034767, 0.005184841342270374, -0.0055184694938361645, 0.003963171970099211, 0.013394459150731564, -0.05619724467396736, 0.037625789642
large-scale tropical print. The design depicts palm leaves and parts of the tree trunk in various shades of green and brown against a white background.\xa0\n\n\nThe floor is a speckled concrete or terrazzo style, with a mix of light and dark aggregates. A dark baseboard runs along the bottom of the wall. A double electrical outlet is visible on the wall near the lower right corner.\n\n\n**BrandsCompanyNamesLogos**\nNone', '06a3f13e018e783f300aae14390a1602d231f25f.jpeg', 0.8628939987483002), {'content': 0, 'combined_id': 1, 'distance': 2})
# Row(('Content: a dark metal base.\xa0 A dark chair is partially visible in the foreground.\xa0 The overall lighting is bright and even, suggesting a daytime scene.', '0599a2d664c368ad6be742ebccd291a733d94ee3.jpeg', 0.8631573886947715), {'content': 0, 'combined_id': 1, 'distance': 2})
# Row(('Content: **DetailedDescription**\nEye-level view of a residential property scene.\xa0\n\n\nThe main subject is a house, light cream/beige in color, with a tiled roof. A portion of the front facade is visible, showing a window and a small porch area.\xa0 A cream-colored wall with a scalloped top edge extends from the house towards the foreground, creating a boundary along the sidewalk and driveway.\xa0\n\n\nThe driveway, made of concrete, leads towards the house and has some dry leaves and debris scattered on it.\xa0 To the left of the driveway, greenery is visible, including a potted plant near the edge of the frame.\xa0\n\n\nVarious shrubs and small trees are planted along the front of the house and beside the wall.\xa0 The sidewalk appears paved and clean.\xa0 Shadows of the trees and wall are cast on the sidewalk and driveway, indicating a sunny day. The sky is clear and blue.\n\n\n**BrandsCompanyNamesLogos**\nNone\n\n\n**KeyLocations**\nResidential area, likely a suburb', '0577062a928e80f510e2fc9b3c55c09d628de7e9.jpeg', 0.8635370782359583), {'content': 0, 'combined_id': 1, 'distance': 2})
# Row(("Content: **DetailedDescription**\nEye-level medium shot of a man, seemingly middle-aged, with light brown hair, wearing a navy blue suit and a white shirt. He is seated and appears relaxed, with his hands resting on his legs.\xa0 The man is positioned slightly off-center within the frame. The background features a series of vertical partitions or panels in various colors, including light wood, teal, and a purplish-red.\xa0 These partitions create a layered effect and suggest a modern, possibly office or public space setting.\xa0 The partitions are not solid but have gaps, allowing some view of the areas beyond. Some gray upholstered furniture, possibly chairs or benches, can be partially seen behind the partitions. The lighting in the image is relatively bright, with some areas of highlight and shadow, particularly on the wooden partitions.\xa0 The man's expression is neutral, almost a slight smile. He is wearing a wedding band on his left hand.\n\n\n**BrandsCompanyNamesLogos**\n\nNone", '09b7d3b61721c41388490b609873f54a815e9682.jpeg', 0.8637706624898718), {'content': 0, 'combined_id': 1, 'distance': 2})
# Row(("Content: **DetailedDescription**\nEye-level, medium shot of a man, likely middle-aged, with short, light gray hair and wearing glasses with dark frames. He is dressed in a brown tweed or textured blazer, a cream-colored turtleneck sweater, and what appears to be a simple band on his left ring finger.\xa0 His arms are folded across his lower abdomen, and his hands are clasped together.\xa0 The man's expression is neutral, and he is looking directly at the camera. The background is out-of-focus but suggests an indoor location, possibly a hallway or corridor, with light-colored walls and some architectural details visible. There's a hint of what might be a green exit sign in the background. The lighting is soft and even, likely from an indoor source.\n\n**BrandsCompanyNamesLogos**\nNone\n\n**KeyLocations**\nIndoor location, likely a hallway or corridor.\n\n**KeyThemes**\nPortrait, business or professional attire.\n\n**PeopleAppearing**\nNone recognizable.", '05d2a5dfa24786444d6e6e7216acfa12012c4c5e.jpeg', 0.8650806419609989), {'content': 0, 'combined_id': 1, 'distance': 2})
